# %% [markdown]
# # Time Series Prediction With MLP and LSTM in Keras

# %% [markdown]
# ##### Data Set:

# %% [markdown]
# International airline passengers prediction problem.
#
#     This is a problem where given a year and a month, the task is to predict the number of international airline passengers in units of 1,000.
#     The data ranges from January 1949 to December 1960 or 12 years, with 144 observations.

# %% [markdown]
# ##### Load required modules

# %%
import numpy
import math
import matplotlib.pyplot as plt

from pandas import DataFrame, concat, read_csv

from keras.models import Sequential
from keras.layers import Dense, LSTM 

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ##### Set current working directory

# %%
import os
PATH = os.getcwd()

# %% [markdown]
# Set directory to the place where data exist

# %%
os.chdir(PATH)

# %% [markdown]
# ##### Fix random seed for reproducibility

# %%
import numpy
numpy.random.seed(123)

# %% [markdown]
# ##### Load this dataset using the Pandas library.

# %% [markdown]
#     Given that each observation is separated by the same interval of one month.
#
#         Exclude the first column.
#
#     The downloaded dataset has footer information.
#
#         That can be exclude with the skipfooter argument to pandas.read_csv() set to 3 for the 3 footer lines.

# %%
dataframe = read_csv('international-airline-passengers.csv', usecols=[1], engine='python', skipfooter=3)

# %%
print (dataframe.head())
# Out:
#    International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 0                                                112
# 1                                                118
# 2                                                132
# 3                                                129
# 4                                                121

# %% [markdown]
# ##### Extract the NumPy array from the dataframe and convert the integer values to floating point values.

# %%
dataset = dataframe.values
dataset = dataset.astype('float32')

# %% [markdown]
# ##### Plot the dataset

# %%
plt.plot(dataset)
plt.show()

# %% [markdown]
# ##### Split the data into train and test
#
#     Note: With time series data, the sequence is important. So split the ordered dataset into train and test.

# %%
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size

train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

print(len(train), len(test))
# Out:
# 96 48

# %% [markdown]
# ##### Normalize the Data
#
#     Normalize the dataset using the MinMaxScaler preprocessing class from the scikit-learn library.

# %%
scaler = MinMaxScaler(feature_range=(0, 1)).fit(train)

train_Scal = scaler.transform(train)

test_Scal = scaler.transform(test)

# %%
print (train_Scal[:10])
# Out:
# [[0.02588999]
#  [0.04530746]
#  [0.09061491]
#  [0.08090615]
#  [0.05501619]
#  [0.10032365]
#  [0.14239484]
#  [0.14239484]
#  [0.10355988]
#  [0.04854369]]

# %% [markdown]
# ## Multilayer Perceptron Regression

# %% [markdown]
# ##### Phrase the time series prediction problem as a regression problem.
#
#     I.e. given the number of passengers this month, what will be the number of passengers next month.

# %% [markdown]
# ##### Write a function to convert single column of data into a two-column dataset.
#
#     The first column containing this month’s (t-1) passenger count and the second column containing next month’s (t) passenger count, to be predicted.

# %% [markdown]
# The function takes two arguments
#
#     The dataset, which is a NumPy array and
#     The look_back, which is the number of previous time steps to use as input variables to predict the next time period (defaulted is 1)
#
#     This default will create a dataset where X is the number of passengers at a given time (t-1) and Y is the number of passengers at the next time (t).

# %%
# Convert an array of values into a dataset matrix
def create_dataset(dataset, look_back = 1):       
    y = DataFrame(dataset)
    X = [y.shift(i) for i in range(1, look_back+1)]
    X = concat(X, axis=1)
    X.fillna(0, inplace = True)
    return X.values, y.values

# %% [markdown]
# ##### Prepare train and test dataset where X = t and Y = t+1
#
#     Using create_dataset function

# %%
look_back = 1

trainX, trainY = create_dataset(train_Scal)
testX, testY = create_dataset(test_Scal)

# %% [markdown]
# ##### Create Multilayer Perceptron model
#     With 1 input, 1 hidden layer with 8 neurons and an output layer.`

# %%
model = Sequential()

model.add(Dense(8, input_dim=look_back, activation='relu'))
model.add(Dense(1))

# %% [markdown]
# ##### Compilte the mode

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1340: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %% [markdown]
# ##### Fit the model

# %%
model.fit(trainX, trainY, epochs=100, batch_size=2, verbose=2)
# Out:
# Epoch 1/100
#  - 0s - loss: 0.1483
# Epoch 2/100
#  - 0s - loss: 0.0726
# Epoch 3/100
#  - 0s - loss: 0.0414
# Epoch 4/100
#  - 0s - loss: 0.0287
# Epoch 5/100
#  - 0s - loss: 0.0230
# Epoch 6/100
#  - 0s - loss: 0.0202
# Epoch 7/100
#  - 0s - loss: 0.0179
# Epoch 8/100
#  - 0s - loss: 0.0164
# Epoch 9/100
#  - 0s - loss: 0.0149
# Epoch 10/100
#  - 0s - loss: 0.0138
# Epoch 11/100
#  - 0s - loss: 0.0128
# Epoch 12/100
#  - 0s - loss: 0.0119
# Epoch 13/100
#  - 0s - loss: 0.0111
# Epoch 14/100
#  - 0s - loss: 0.0104
# Epoch 15/100
#  - 0s - loss: 0.0099
# Epoch 16/100
#  - 0s - loss: 0.0095
# Epoch 17/100
#  - 0s - loss: 0.0090
# Epoch 18/100
#  - 0s - loss: 0.0085
# Epoch 19/100
#  - 0s - loss: 0.0082
# Epoch 20/100
#  - 0s - loss: 0.0079
# Epoch 21/100
#  - 0s - loss: 0.0075
# Epoch 22/100
#  - 0s - loss: 0.0073
# Epoch 23/100
#  - 0s - loss: 0.0070
# Epoch 24/100
#  - 0s - loss: 0.0068
# Epoch 25/100
#  - 0s - loss: 0.0066
# Epoch 26/100
#  - 0s - loss: 0.0064
# Epoch 27/100
#  - 0s - loss: 0.0064
# Epoch 28/100
#  - 0s - loss: 0.0061
# Epoch 29/100
#  - 0s - loss: 0.0060
# Epoch 30/100
#  - 0s - loss: 0.0060
# Epoch 31/100
#  - 0s - loss: 0.0060
# Epoch 32/100
#  - 0s - loss: 0.0058
# Epoch 33/100
#  - 0s - loss: 0.0057
# Epoch 34/100
#  - 0s - loss: 0.0057
# Epoch 35/100
#  - 0s - loss: 0.0057
# Epoch 36/100
#  - 0s - loss: 0.0057
# Epoch 37/100
#  - 0s - loss: 0.0056
# Epoch 38/100
#  - 0s - loss: 0.0056
# Epoch 39/100
#  - 0s - loss: 0.0056
# Epoch 40/100
#  - 0s - loss: 0.0055
# Epoch 41/100
#  - 0s - loss: 0.0055
# Epoch 42/100
#  - 0s - loss: 0.0056
# Epoch 43/100
#  - 0s - loss: 0.0055
# Epoch 44/100
#  - 0s - loss: 0.0056
# Epoch 45/100
#  - 0s - loss: 0.0055
# Epoch 46/100
#  - 0s - loss: 0.0055
# Epoch 47/100
#  - 0s - loss: 0.0055
# Epoch 48/100
#  - 0s - loss: 0.0055
# Epoch 49/100
#  - 0s - loss: 0.0055
# Epoch 50/100
#  - 0s - loss: 0.0055
# Epoch 51/100
#  - 0s - loss: 0.0055
# Epoch 52/100
#  - 0s - loss: 0.0055
# Epoch 53/100
#  - 0s - loss: 0.0055
# Epoch 54/100
#  - 0s - loss: 0.0055
# Epoch 55/100
#  - 0s - loss: 0.0055
# Epoch 56/100
#  - 0s - loss: 0.0055
# Epoch 57/100
#  - 0s - loss: 0.0055
# Epoch 58/100
#  - 0s - loss: 0.0055
# Epoch 59/100
#  - 0s - loss: 0.0055
# Epoch 60/100
#  - 0s - loss: 0.0055
# Epoch 61/100
#  - 0s - loss: 0.0055
# Epoch 62/100
#  - 0s - loss: 0.0055
# Epoch 63/100
#  - 0s - loss: 0.0055
# Epoch 64/100
#  - 0s - loss: 0.0055
# Epoch 65/100
#  - 0s - loss: 0.0056
# Epoch 66/100
#  - 0s - loss: 0.0055
# Epoch 67/100
#  - 0s - loss: 0.0055
# Epoch 68/100
#  - 0s - loss: 0.0055
# Epoch 69/100
#  - 0s - loss: 0.0055
# Epoch 70/100
#  - 0s - loss: 0.0056
# Epoch 71/100
#  - 0s - loss: 0.0055
# Epoch 72/100
#  - 0s - loss: 0.0055
# Epoch 73/100
#  - 0s - loss: 0.0055
# Epoch 74/100
#  - 0s - loss: 0.0055
# Epoch 75/100
#  - 0s - loss: 0.0055
# Epoch 76/100
#  - 0s - loss: 0.0055
# Epoch 77/100
#  - 0s - loss: 0.0055
# Epoch 78/100
#  - 0s - loss: 0.0054
# Epoch 79/100
#  - 0s - loss: 0.0055
# Epoch 80/100
#  - 0s - loss: 0.0055
# Epoch 81/100
#  - 0s - loss: 0.0055
# Epoch 82/100
#  - 0s - loss: 0.0055
# Epoch 83/100
#  - 0s - loss: 0.0055
# Epoch 84/100
#  - 0s - loss: 0.0055
# Epoch 85/100
#  - 0s - loss: 0.0055
# Epoch 86/100
#  - 0s - loss: 0.0055
# Epoch 87/100
#  - 0s - loss: 0.0055
# Epoch 88/100
#  - 0s - loss: 0.0056
# Epoch 89/100
#  - 0s - loss: 0.0055
# Epoch 90/100
#  - 0s - loss: 0.0055
# Epoch 91/100
#  - 0s - loss: 0.0055
# Epoch 92/100
#  - 0s - loss: 0.0055
# Epoch 93/100
#  - 0s - loss: 0.0055
# Epoch 94/100
#  - 0s - loss: 0.0055
# Epoch 95/100
#  - 0s - loss: 0.0055
# Epoch 96/100
#  - 0s - loss: 0.0055
# Epoch 97/100
#  - 0s - loss: 0.0056
# Epoch 98/100
#  - 0s - loss: 0.0055
# Epoch 99/100
#  - 0s - loss: 0.0055
# Epoch 100/100
#  - 0s - loss: 0.0055

# %% [markdown]
# ##### Estimate the performance of the model

# %%
# Estimate model performance
trainScore = model.evaluate(trainX, trainY, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = model.evaluate(testX, testY, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 0.01 MSE (0.07 RMSE)
# Test Score: 0.03 MSE (0.19 RMSE)

# %% [markdown]
# ##### Predictions using the built model

# %%
trainPredict_Scal = model.predict(trainX)

testPredict_Scal = model.predict(testX)

# %% [markdown]
# ##### Invert the predictions back to same units as the original data

# %%
trainPredict = scaler.inverse_transform(trainPredict_Scal)

testPredict = scaler.inverse_transform(testPredict_Scal)

# %% [markdown]
# ##### Plot the data
#
#     Because of how the dataset was prepared, we must shift the predictions so that they aline with the original data on on the x-axis.

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[:len(trainPredict), :] = trainPredict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict):, :] = testPredict

# %%
# %matplotlib notebook
# plot baseline and predictions
plt.plot(dataset)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Multilayer Perceptron Using the Window Method

# %% [markdown]
# Multiple recent time steps can be used to make the prediction for the next time step. This is called the window method, and the size of the window is a parameter that can be tuned for each problem.
#
#     E.g. time (t-2), time (t-1), and time (t) can be used predict time (t+1).

# %% [markdown]
# ##### Prepare train and test dataset where X = t-2, t-1, t and Y = t+1
#
#     Using create_dataset function

# %%
look_back = 3
trainX, trainY = create_dataset(train_Scal, look_back)
testX, testY = create_dataset(test_Scal, look_back)

# %%
print (trainX)
# Out:
# [[0.         0.         0.        ]
#  [0.02588999 0.         0.        ]
#  [0.04530746 0.02588999 0.        ]
#  [0.09061491 0.04530746 0.02588999]
#  [0.08090615 0.09061491 0.04530746]
#  [0.05501619 0.08090615 0.09061491]
#  [0.10032365 0.05501619 0.08090615]
#  [0.14239484 0.10032365 0.05501619]
#  [0.14239484 0.14239484 0.10032365]
#  [0.10355988 0.14239484 0.14239484]
#  [0.04854369 0.10355988 0.14239484]
#  [0.         0.04854369 0.10355988]
#  [0.04530746 0.         0.04854369]
#  [0.03559873 0.04530746 0.        ]
#  [0.07119742 0.03559873 0.04530746]
#  [0.11974111 0.07119742 0.03559873]
#  [0.10032365 0.11974111 0.07119742]
#  [0.06796119 0.10032365 0.11974111]
#  [0.14563107 0.06796119 0.10032365]
#  [0.21359226 0.14563107 0.06796119]
#  [0.21359226 0.21359226 0.14563107]
#  [0.17475727 0.21359226 0.21359226]
#  [0.09385115 0.17475727 0.21359226]
#  [0.03236246 0.09385115 0.17475727]
#  [0.11650488 0.03236246 0.09385115]
#  [0.13268611 0.11650488 0.03236246]
#  [0.14886734 0.13268611 0.11650488]
#  [0.2394822  0.14886734 0.13268611]
#  [0.1909385  0.2394822  0.14886734]
#  [0.22006473 0.1909385  0.2394822 ]
#  [0.2394822  0.22006473 0.1909385 ]
#  [0.3074434  0.2394822  0.22006473]
#  [0.3074434  0.3074434  0.2394822 ]
#  [0.25889972 0.3074434  0.3074434 ]
#  [0.18770227 0.25889972 0.3074434 ]
#  [0.13592234 0.18770227 0.25889972]
#  [0.20064726 0.13592234 0.18770227]
#  [0.2168285  0.20064726 0.13592234]
#  [0.24595472 0.2168285  0.20064726]
#  [0.2880259  0.24595472 0.2168285 ]
#  [0.24919096 0.2880259  0.24595472]
#  [0.25566342 0.24919096 0.2880259 ]
#  [0.36893204 0.25566342 0.24919096]
#  [0.40776703 0.36893204 0.25566342]
#  [0.44660196 0.40776703 0.36893204]
#  [0.33980587 0.44660196 0.40776703]
#  [0.28155342 0.33980587 0.44660196]
#  [0.22006473 0.28155342 0.33980587]
#  [0.29126218 0.22006473 0.28155342]
#  [0.29773465 0.29126218 0.22006473]
#  [0.29773465 0.29773465 0.29126218]
#  [0.4271845  0.29773465 0.29773465]
#  [0.42394826 0.4271845  0.29773465]
#  [0.4045308  0.42394826 0.4271845 ]
#  [0.4498382  0.4045308  0.42394826]
#  [0.5177994  0.4498382  0.4045308 ]
#  [0.54368937 0.5177994  0.4498382 ]
#  [0.43042073 0.54368937 0.5177994 ]
#  [0.34627834 0.43042073 0.54368937]
#  [0.24595472 0.34627834 0.43042073]
#  [0.31391588 0.24595472 0.34627834]
#  [0.32362464 0.31391588 0.24595472]
#  [0.27184466 0.32362464 0.31391588]
#  [0.42394826 0.27184466 0.32362464]
#  [0.39805827 0.42394826 0.27184466]
#  [0.42071202 0.39805827 0.42394826]
#  [0.5177994  0.42071202 0.39805827]
#  [0.64077675 0.5177994  0.42071202]
#  [0.61165047 0.64077675 0.5177994 ]
#  [0.50161815 0.61165047 0.64077675]
#  [0.4045308  0.50161815 0.61165047]
#  [0.32038835 0.4045308  0.50161815]
#  [0.4045308  0.32038835 0.4045308 ]
#  [0.44660196 0.4045308  0.32038835]
#  [0.41747573 0.44660196 0.4045308 ]
#  [0.52750814 0.41747573 0.44660196]
#  [0.5339806  0.52750814 0.41747573]
#  [0.5372169  0.5339806  0.52750814]
#  [0.682848   0.5372169  0.5339806 ]
#  [0.841424   0.682848   0.5372169 ]
#  [0.7864078  0.841424   0.682848  ]
#  [0.6731392  0.7864078  0.841424  ]
#  [0.55016184 0.6731392  0.7864078 ]
#  [0.43042073 0.55016184 0.6731392 ]
#  [0.5631068  0.43042073 0.55016184]
#  [0.5825243  0.5631068  0.43042073]
#  [0.5598706  0.5825243  0.5631068 ]
#  [0.68932045 0.5598706  0.5825243 ]
#  [0.6763755  0.68932045 0.5598706 ]
#  [0.69255674 0.6763755  0.68932045]
#  [0.87378645 0.69255674 0.6763755 ]
#  [1.0000001  0.87378645 0.69255674]
#  [0.9741101  1.0000001  0.87378645]
#  [0.8122978  0.9741101  1.0000001 ]
#  [0.6537217  0.8122978  0.9741101 ]
#  [0.5404531  0.6537217  0.8122978 ]]

# %% [markdown]
# ##### Create Multilayer Perceptron model
#     With 3 input, 1 hidden layer with 8 neurons and an output layer.`

# %%
model = Sequential()
model.add(Dense(8, input_dim=look_back, activation='relu'))
model.add(Dense(1))

# %% [markdown]
# ##### Compile the model

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# ##### Fit the model

# %%
model.fit(trainX, trainY, epochs=100, batch_size=2, verbose=2)
# Out:
# Epoch 1/100
#  - 0s - loss: 0.0228
# Epoch 2/100
#  - 0s - loss: 0.0109
# Epoch 3/100
#  - 0s - loss: 0.0093
# Epoch 4/100
#  - 0s - loss: 0.0084
# Epoch 5/100
#  - 0s - loss: 0.0081
# Epoch 6/100
#  - 0s - loss: 0.0075
# Epoch 7/100
#  - 0s - loss: 0.0075
# Epoch 8/100
#  - 0s - loss: 0.0070
# Epoch 9/100
#  - 0s - loss: 0.0066
# Epoch 10/100
#  - 0s - loss: 0.0066
# Epoch 11/100
#  - 0s - loss: 0.0063
# Epoch 12/100
#  - 0s - loss: 0.0064
# Epoch 13/100
#  - 0s - loss: 0.0061
# Epoch 14/100
#  - 0s - loss: 0.0061
# Epoch 15/100
#  - 0s - loss: 0.0062
# Epoch 16/100
#  - 0s - loss: 0.0066
# Epoch 17/100
#  - 0s - loss: 0.0060
# Epoch 18/100
#  - 0s - loss: 0.0062
# Epoch 19/100
#  - 0s - loss: 0.0059
# Epoch 20/100
#  - 0s - loss: 0.0058
# Epoch 21/100
#  - 0s - loss: 0.0060
# Epoch 22/100
#  - 0s - loss: 0.0058
# Epoch 23/100
#  - 0s - loss: 0.0060
# Epoch 24/100
#  - 0s - loss: 0.0056
# Epoch 25/100
#  - 0s - loss: 0.0068
# Epoch 26/100
#  - 0s - loss: 0.0060
# Epoch 27/100
#  - 0s - loss: 0.0056
# Epoch 28/100
#  - 0s - loss: 0.0055
# Epoch 29/100
#  - 0s - loss: 0.0055
# Epoch 30/100
#  - 0s - loss: 0.0056
# Epoch 31/100
#  - 0s - loss: 0.0054
# Epoch 32/100
#  - 0s - loss: 0.0057
# Epoch 33/100
#  - 0s - loss: 0.0059
# Epoch 34/100
#  - 0s - loss: 0.0055
# Epoch 35/100
#  - 0s - loss: 0.0052
# Epoch 36/100
#  - 0s - loss: 0.0056
# Epoch 37/100
#  - 0s - loss: 0.0055
# Epoch 38/100
#  - 0s - loss: 0.0055
# Epoch 39/100
#  - 0s - loss: 0.0054
# Epoch 40/100
#  - 0s - loss: 0.0055
# Epoch 41/100
#  - 0s - loss: 0.0053
# Epoch 42/100
#  - 0s - loss: 0.0056
# Epoch 43/100
#  - 0s - loss: 0.0054
# Epoch 44/100
#  - 0s - loss: 0.0052
# Epoch 45/100
#  - 0s - loss: 0.0055
# Epoch 46/100
#  - 0s - loss: 0.0053
# Epoch 47/100
#  - 0s - loss: 0.0050
# Epoch 48/100
#  - 0s - loss: 0.0054
# Epoch 49/100
#  - 0s - loss: 0.0055
# Epoch 50/100
#  - 0s - loss: 0.0054
# Epoch 51/100
#  - 0s - loss: 0.0054
# Epoch 52/100
#  - 0s - loss: 0.0059
# Epoch 53/100
#  - 0s - loss: 0.0051
# Epoch 54/100
#  - 0s - loss: 0.0053
# Epoch 55/100
#  - 0s - loss: 0.0052
# Epoch 56/100
#  - 0s - loss: 0.0057
# Epoch 57/100
#  - 0s - loss: 0.0051
# Epoch 58/100
#  - 0s - loss: 0.0052
# Epoch 59/100
#  - 0s - loss: 0.0052
# Epoch 60/100
#  - 0s - loss: 0.0051
# Epoch 61/100
#  - 0s - loss: 0.0053
# Epoch 62/100
#  - 0s - loss: 0.0049
# Epoch 63/100
#  - 0s - loss: 0.0053
# Epoch 64/100
#  - 0s - loss: 0.0051
# Epoch 65/100
#  - 0s - loss: 0.0053
# Epoch 66/100
#  - 0s - loss: 0.0052
# Epoch 67/100
#  - 0s - loss: 0.0050
# Epoch 68/100
#  - 0s - loss: 0.0052
# Epoch 69/100
#  - 0s - loss: 0.0052
# Epoch 70/100
#  - 0s - loss: 0.0051
# Epoch 71/100
#  - 0s - loss: 0.0053
# Epoch 72/100
#  - 0s - loss: 0.0053
# Epoch 73/100
#  - 0s - loss: 0.0056
# Epoch 74/100
#  - 0s - loss: 0.0057
# Epoch 75/100
#  - 0s - loss: 0.0049
# Epoch 76/100
#  - 0s - loss: 0.0052
# Epoch 77/100
#  - 0s - loss: 0.0053
# Epoch 78/100
#  - 0s - loss: 0.0051
# Epoch 79/100
#  - 0s - loss: 0.0051
# Epoch 80/100
#  - 0s - loss: 0.0055
# Epoch 81/100
#  - 0s - loss: 0.0056
# Epoch 82/100
#  - 0s - loss: 0.0051
# Epoch 83/100
#  - 0s - loss: 0.0052
# Epoch 84/100
#  - 0s - loss: 0.0051
# Epoch 85/100
#  - 0s - loss: 0.0051
# Epoch 86/100
#  - 0s - loss: 0.0049
# Epoch 87/100
#  - 0s - loss: 0.0052
# Epoch 88/100
#  - 0s - loss: 0.0050
# Epoch 89/100
#  - 0s - loss: 0.0052
# Epoch 90/100
#  - 0s - loss: 0.0053
# Epoch 91/100
#  - 0s - loss: 0.0051
# Epoch 92/100
#  - 0s - loss: 0.0054
# Epoch 93/100
#  - 0s - loss: 0.0054
# Epoch 94/100
#  - 0s - loss: 0.0049
# Epoch 95/100
#  - 0s - loss: 0.0047
# Epoch 96/100
#  - 0s - loss: 0.0053
# Epoch 97/100
#  - 0s - loss: 0.0053
# Epoch 98/100
#  - 0s - loss: 0.0053
# Epoch 99/100
#  - 0s - loss: 0.0051
# Epoch 100/100
#  - 0s - loss: 0.0051

# %% [markdown]
# ##### Estimate the performance of the model

# %%
# Estimate model performance
trainScore = model.evaluate(trainX, trainY, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = model.evaluate(testX, testY, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 0.00 MSE (0.07 RMSE)
# Test Score: 0.03 MSE (0.18 RMSE)

# %% [markdown]
# ##### Predictions using the built model

# %%
trainPredict_Scal = model.predict(trainX)
testPredict_Scal = model.predict(testX)

# %% [markdown]
# ##### Invert the predictions back to same units as the original data

# %%
trainPredict = scaler.inverse_transform(trainPredict_Scal)

testPredict = scaler.inverse_transform(testPredict_Scal)

# %% [markdown]
# #### Preparte and plot the data

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[:len(trainPredict), :] = trainPredict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict):, :] = testPredict

# %%
# %matplotlib notebook

# plot baseline and predictions
plt.plot(dataset)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## LSTM Recurrent Neural Networks for Time Series

# %% [markdown]
#     Unlike regression predictive modeling, time series also adds the complexity of a sequence dependence among the input variables.
#     A powerful type of neural network designed to handle sequence dependence is called recurrent neural networks.

# %% [markdown]
# ##### Prepare the train and test datasets
#     Using create_dataset function

# %%
# reshape into X = t and Y = t+1
look_back = 1

trainX, trainY = create_dataset(train_Scal)
testX, testY = create_dataset(test_Scal)

# %% [markdown]
# #### The LSTM network expects the input data (X) to be provided with a specific array structure in the form
#
#     [samples, time steps, features].

# %% [markdown]
# Currently, our data is in the form: [samples, features]
#
# We are framing the problem as one time step for each sample.
#
# ##### Transform the train and test input data into the expected structure using numpy.reshape()

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# ###### Design and fit our LSTM network for this problem.
#
# The network has
#
#     A visible layer with 1 input,
#     A hidden layer with 4 LSTM blocks or neurons, and
#     An output layer that makes a single value prediction.
#     The default sigmoid activation function is used for the LSTM blocks.
#     The network is trained for 100 epochs and a batch size of 1 is used.

# %% [markdown]
# ##### Create the LSTM network

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(1,look_back)))
model.add(Dense(1))

# %% [markdown]
# ##### Compile the LSTM network

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# ##### Fit the LSTM network

# %%
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
#  - 1s - loss: 0.1161
# Epoch 2/100
#  - 1s - loss: 0.0609
# Epoch 3/100
#  - 0s - loss: 0.0386
# Epoch 4/100
#  - 0s - loss: 0.0318
# Epoch 5/100
#  - 0s - loss: 0.0284
# Epoch 6/100
#  - 0s - loss: 0.0256
# Epoch 7/100
#  - 0s - loss: 0.0232
# Epoch 8/100
#  - 1s - loss: 0.0207
# Epoch 9/100
#  - 0s - loss: 0.0185
# Epoch 10/100
#  - 0s - loss: 0.0162
# Epoch 11/100
#  - 1s - loss: 0.0143
# Epoch 12/100
#  - 0s - loss: 0.0123
# Epoch 13/100
#  - 0s - loss: 0.0107
# Epoch 14/100
#  - 0s - loss: 0.0096
# Epoch 15/100
#  - 0s - loss: 0.0083
# Epoch 16/100
#  - 0s - loss: 0.0076
# Epoch 17/100
#  - 1s - loss: 0.0070
# Epoch 18/100
#  - 0s - loss: 0.0066
# Epoch 19/100
#  - 0s - loss: 0.0062
# Epoch 20/100
#  - 0s - loss: 0.0060
# Epoch 21/100
#  - 0s - loss: 0.0059
# Epoch 22/100
#  - 0s - loss: 0.0058
# Epoch 23/100
#  - 0s - loss: 0.0057
# Epoch 24/100
#  - 0s - loss: 0.0058
# Epoch 25/100
#  - 0s - loss: 0.0057
# Epoch 26/100
#  - 0s - loss: 0.0058
# Epoch 27/100
#  - 0s - loss: 0.0056
# Epoch 28/100
#  - 0s - loss: 0.0057
# Epoch 29/100
#  - 0s - loss: 0.0056
# Epoch 30/100
#  - 1s - loss: 0.0057
# Epoch 31/100
#  - 0s - loss: 0.0057
# Epoch 32/100
#  - 0s - loss: 0.0055
# Epoch 33/100
#  - 0s - loss: 0.0058
# Epoch 34/100
#  - 0s - loss: 0.0054
# Epoch 35/100
#  - 0s - loss: 0.0057
# Epoch 36/100
#  - 0s - loss: 0.0057
# Epoch 37/100
#  - 0s - loss: 0.0057
# Epoch 38/100
#  - 0s - loss: 0.0057
# Epoch 39/100
#  - 0s - loss: 0.0056
# Epoch 40/100
#  - 0s - loss: 0.0056
# Epoch 41/100
#  - 0s - loss: 0.0057
# Epoch 42/100
#  - 0s - loss: 0.0057
# Epoch 43/100
#  - 0s - loss: 0.0057
# Epoch 44/100
#  - 0s - loss: 0.0057
# Epoch 45/100
#  - 0s - loss: 0.0057
# Epoch 46/100
#  - 0s - loss: 0.0056
# Epoch 47/100
#  - 0s - loss: 0.0056
# Epoch 48/100
#  - 0s - loss: 0.0056
# Epoch 49/100
#  - 0s - loss: 0.0056
# Epoch 50/100
#  - 0s - loss: 0.0055
# Epoch 51/100
#  - 0s - loss: 0.0056
# Epoch 52/100
#  - 0s - loss: 0.0056
# Epoch 53/100
#  - 0s - loss: 0.0057
# Epoch 54/100
#  - 0s - loss: 0.0056
# Epoch 55/100
#  - 0s - loss: 0.0056
# Epoch 56/100
#  - 0s - loss: 0.0058
# Epoch 57/100
#  - 0s - loss: 0.0057
# Epoch 58/100
#  - 0s - loss: 0.0056
# Epoch 59/100
#  - 0s - loss: 0.0057
# Epoch 60/100
#  - 0s - loss: 0.0056
# Epoch 61/100
#  - 0s - loss: 0.0056
# Epoch 62/100
#  - 0s - loss: 0.0056
# Epoch 63/100
#  - 0s - loss: 0.0055
# Epoch 64/100
#  - 0s - loss: 0.0057
# Epoch 65/100
#  - 0s - loss: 0.0057
# Epoch 66/100
#  - 0s - loss: 0.0057
# Epoch 67/100
#  - 0s - loss: 0.0056
# Epoch 68/100
#  - 0s - loss: 0.0057
# Epoch 69/100
#  - 0s - loss: 0.0055
# Epoch 70/100
#  - 0s - loss: 0.0056
# Epoch 71/100
#  - 0s - loss: 0.0056
# Epoch 72/100
#  - 0s - loss: 0.0055
# Epoch 73/100
#  - 0s - loss: 0.0057
# Epoch 74/100
#  - 0s - loss: 0.0053
# Epoch 75/100
#  - 0s - loss: 0.0059
# Epoch 76/100
#  - 0s - loss: 0.0057
# Epoch 77/100
#  - 0s - loss: 0.0055
# Epoch 78/100
#  - 0s - loss: 0.0057
# Epoch 79/100
#  - 0s - loss: 0.0057
# Epoch 80/100
#  - 0s - loss: 0.0056
# Epoch 81/100
#  - 0s - loss: 0.0055
# Epoch 82/100
#  - 0s - loss: 0.0055
# Epoch 83/100
#  - 0s - loss: 0.0056
# Epoch 84/100
#  - 0s - loss: 0.0055
# Epoch 85/100
#  - 0s - loss: 0.0056
# Epoch 86/100
#  - 0s - loss: 0.0056
# Epoch 87/100
#  - 0s - loss: 0.0056
# Epoch 88/100
#  - 0s - loss: 0.0056
# Epoch 89/100
#  - 0s - loss: 0.0056
# Epoch 90/100
#  - 0s - loss: 0.0056
# Epoch 91/100
#  - 0s - loss: 0.0056
# Epoch 92/100
#  - 0s - loss: 0.0057
# Epoch 93/100
#  - 0s - loss: 0.0057
# Epoch 94/100
#  - 0s - loss: 0.0056
# Epoch 95/100
#  - 0s - loss: 0.0056
# Epoch 96/100
#  - 0s - loss: 0.0056
# Epoch 97/100
#  - 0s - loss: 0.0055
# Epoch 98/100
#  - 0s - loss: 0.0055
# Epoch 99/100
#  - 0s - loss: 0.0056
# Epoch 100/100
#  - 0s - loss: 0.0055

# %% [markdown]
# ##### Estimate the performance of the model

# %%
# Estimate model performance
trainScore = model.evaluate(trainX, trainY, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = model.evaluate(testX, testY, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 0.01 MSE (0.07 RMSE)
# Test Score: 0.03 MSE (0.18 RMSE)

# %% [markdown]
# ##### Predictions using the built model

# %%
trainPredict_Scal = model.predict(trainX)
testPredict_Scal = model.predict(testX)

# %% [markdown]
# Invert the predictions before calculating error scores to ensure that performance is reported in the same units as the original data

# %%
trainPredict = scaler.inverse_transform(trainPredict_Scal)

testPredict = scaler.inverse_transform(testPredict_Scal)

# %% [markdown]
# #### Preparte and plot the data

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[:len(trainPredict), :] = trainPredict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict):, :] = testPredict

# %%
# %matplotlib notebook

# plot baseline and predictions
plt.plot(dataset)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### LSTM for Regression Using the Window Method

# %% [markdown]
# ##### Create train and test data
#     Input variables are t-2, t-1, t and the output variable is t+1.

# %%
look_back = 3

trainX, trainY = create_dataset(train_Scal, look_back)
testX, testY = create_dataset(test_Scal, look_back)

# %% [markdown]
# The LSTM network expects the input data (X) to be provided with a specific array structure in the form
#
#     [samples, time steps, features].

# %% [markdown]
# ##### Reshape input to be [samples, time steps, features]

# %%
print (trainX[:10], trainX.shape)
# Out:
# [[ 0.          0.          0.        ]
#  [ 0.02588999  0.          0.        ]
#  [ 0.04530746  0.02588999  0.        ]
#  [ 0.09061491  0.04530746  0.02588999]
#  [ 0.08090615  0.09061491  0.04530746]
#  [ 0.05501619  0.08090615  0.09061491]
#  [ 0.10032365  0.05501619  0.08090615]
#  [ 0.14239484  0.10032365  0.05501619]
#  [ 0.14239484  0.14239484  0.10032365]
#  [ 0.10355988  0.14239484  0.14239484]] (96, 3)

# %%
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
print (trainX[:10], trainX.shape)
# Out:
# [[[ 0.          0.          0.        ]]
#
#  [[ 0.02588999  0.          0.        ]]
#
#  [[ 0.04530746  0.02588999  0.        ]]
#
#  [[ 0.09061491  0.04530746  0.02588999]]
#
#  [[ 0.08090615  0.09061491  0.04530746]]
#
#  [[ 0.05501619  0.08090615  0.09061491]]
#
#  [[ 0.10032365  0.05501619  0.08090615]]
#
#  [[ 0.14239484  0.10032365  0.05501619]]
#
#  [[ 0.14239484  0.14239484  0.10032365]]
#
#  [[ 0.10355988  0.14239484  0.14239484]]] (96, 1, 3)

# %% [markdown]
# ##### Create the LSTM network

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(1,look_back)))
model.add(Dense(1))

# %% [markdown]
# ##### Compile the LSTM network

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# Model Summary

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 4)                 128
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 133
# Trainable params: 133
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.layer_utils import print_summary
print_summary(model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 4)                 128
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 133
# Trainable params: 133
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Fit the LSTM network

# %%
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
#  - 1s - loss: 0.1857
# Epoch 2/100
#  - 0s - loss: 0.0924
# Epoch 3/100
#  - 0s - loss: 0.0511
# Epoch 4/100
#  - 0s - loss: 0.0362
# Epoch 5/100
#  - 0s - loss: 0.0303
# Epoch 6/100
#  - 0s - loss: 0.0266
# Epoch 7/100
#  - 0s - loss: 0.0234
# Epoch 8/100
#  - 0s - loss: 0.0207
# Epoch 9/100
#  - 0s - loss: 0.0181
# Epoch 10/100
#  - 0s - loss: 0.0163
# Epoch 11/100
#  - 0s - loss: 0.0145
# Epoch 12/100
#  - 0s - loss: 0.0132
# Epoch 13/100
#  - 0s - loss: 0.0120
# Epoch 14/100
#  - 0s - loss: 0.0113
# Epoch 15/100
#  - 0s - loss: 0.0105
# Epoch 16/100
#  - 0s - loss: 0.0099
# Epoch 17/100
#  - 0s - loss: 0.0096
# Epoch 18/100
#  - 0s - loss: 0.0092
# Epoch 19/100
#  - 0s - loss: 0.0092
# Epoch 20/100
#  - 0s - loss: 0.0089
# Epoch 21/100
#  - 0s - loss: 0.0089
# Epoch 22/100
#  - 0s - loss: 0.0087
# Epoch 23/100
#  - 0s - loss: 0.0085
# Epoch 24/100
#  - 0s - loss: 0.0085
# Epoch 25/100
#  - 0s - loss: 0.0083
# Epoch 26/100
#  - 0s - loss: 0.0082
# Epoch 27/100
#  - 0s - loss: 0.0081
# Epoch 28/100
#  - 0s - loss: 0.0080
# Epoch 29/100
#  - 0s - loss: 0.0080
# Epoch 30/100
#  - 0s - loss: 0.0080
# Epoch 31/100
#  - 0s - loss: 0.0079
# Epoch 32/100
#  - 0s - loss: 0.0079
# Epoch 33/100
#  - 0s - loss: 0.0078
# Epoch 34/100
#  - 0s - loss: 0.0078
# Epoch 35/100
#  - 0s - loss: 0.0077
# Epoch 36/100
#  - 0s - loss: 0.0075
# Epoch 37/100
#  - 0s - loss: 0.0076
# Epoch 38/100
#  - 0s - loss: 0.0075
# Epoch 39/100
#  - 0s - loss: 0.0074
# Epoch 40/100
#  - 0s - loss: 0.0074
# Epoch 41/100
#  - 0s - loss: 0.0073
# Epoch 42/100
#  - 0s - loss: 0.0073
# Epoch 43/100
#  - 0s - loss: 0.0072
# Epoch 44/100
#  - 0s - loss: 0.0073
# Epoch 45/100
#  - 0s - loss: 0.0072
# Epoch 46/100
#  - 0s - loss: 0.0072
# Epoch 47/100
#  - 0s - loss: 0.0070
# Epoch 48/100
#  - 0s - loss: 0.0071
# Epoch 49/100
#  - 0s - loss: 0.0071
# Epoch 50/100
#  - 0s - loss: 0.0071
# Epoch 51/100
#  - 0s - loss: 0.0069
# Epoch 52/100
#  - 0s - loss: 0.0070
# Epoch 53/100
#  - 0s - loss: 0.0069
# Epoch 54/100
#  - 0s - loss: 0.0068
# Epoch 55/100
#  - 0s - loss: 0.0068
# Epoch 56/100
#  - 0s - loss: 0.0068
# Epoch 57/100
#  - 0s - loss: 0.0066
# Epoch 58/100
#  - 0s - loss: 0.0066
# Epoch 59/100
#  - 0s - loss: 0.0069
# Epoch 60/100
#  - 0s - loss: 0.0066
# Epoch 61/100
#  - 0s - loss: 0.0066
# Epoch 62/100
#  - 0s - loss: 0.0065
# Epoch 63/100
#  - 0s - loss: 0.0067
# Epoch 64/100
#  - 0s - loss: 0.0066
# Epoch 65/100
#  - 0s - loss: 0.0065
# Epoch 66/100
#  - 0s - loss: 0.0064
# Epoch 67/100
#  - 0s - loss: 0.0065
# Epoch 68/100
#  - 0s - loss: 0.0065
# Epoch 69/100
#  - 0s - loss: 0.0065
# Epoch 70/100
#  - 0s - loss: 0.0065
# Epoch 71/100
#  - 0s - loss: 0.0064
# Epoch 72/100
#  - 0s - loss: 0.0063
# Epoch 73/100
#  - 0s - loss: 0.0064
# Epoch 74/100
#  - 0s - loss: 0.0063
# Epoch 75/100
#  - 0s - loss: 0.0063
# Epoch 76/100
#  - 0s - loss: 0.0062
# Epoch 77/100
#  - 0s - loss: 0.0063
# Epoch 78/100
#  - 0s - loss: 0.0062
# Epoch 79/100
#  - 0s - loss: 0.0062
# Epoch 80/100
#  - 0s - loss: 0.0062
# Epoch 81/100
#  - 0s - loss: 0.0062
# Epoch 82/100
#  - 0s - loss: 0.0061
# Epoch 83/100
#  - 0s - loss: 0.0061
# Epoch 84/100
#  - 0s - loss: 0.0061
# Epoch 85/100
#  - 0s - loss: 0.0062
# Epoch 86/100
#  - 0s - loss: 0.0061
# Epoch 87/100
#  - 0s - loss: 0.0063
# Epoch 88/100
#  - 0s - loss: 0.0061
# Epoch 89/100
#  - 0s - loss: 0.0060
# Epoch 90/100
#  - 0s - loss: 0.0060
# Epoch 91/100
#  - 0s - loss: 0.0060
# Epoch 92/100
#  - 0s - loss: 0.0061
# Epoch 93/100
#  - 0s - loss: 0.0059
# Epoch 94/100
#  - 0s - loss: 0.0059
# Epoch 95/100
#  - 0s - loss: 0.0060
# Epoch 96/100
#  - 0s - loss: 0.0059
# Epoch 97/100
#  - 0s - loss: 0.0059
# Epoch 98/100
#  - 0s - loss: 0.0058
# Epoch 99/100
#  - 0s - loss: 0.0059
# Epoch 100/100
#  - 0s - loss: 0.0062

# %% [markdown]
# ##### Estimate the performance of the model

# %%
# Estimate model performance
trainScore = model.evaluate(trainX, trainY, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = model.evaluate(testX, testY, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 0.01 MSE (0.08 RMSE)
# Test Score: 0.07 MSE (0.26 RMSE)

# %% [markdown]
# ##### Predictions using the built model

# %%
trainPredict_Scal = model.predict(trainX)
testPredict_Scal = model.predict(testX)

# %% [markdown]
# ##### Invert the predictions back to same units as the original data

# %%
trainPredict = scaler.inverse_transform(trainPredict_Scal)

testPredict = scaler.inverse_transform(testPredict_Scal)

# %% [markdown]
# #### Preparte and plot the data

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[:len(trainPredict), :] = trainPredict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict):, :] = testPredict

# %%
# %matplotlib notebook

# plot baseline and predictions
plt.plot(dataset)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### LSTM for Regression with Time Steps

# %% [markdown]
# Instead of phrasing the past observations as separate input features, we can use them as time steps of the one input feature.

# %%
# reshape into X=t-2, t-1, t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train_Scal, look_back)
testX, testY = create_dataset(test_Scal, look_back)

# %% [markdown]
# The LSTM network expects the input data (X) to be provided with a specific array structure in the form
#
#     [samples, time steps, features].

# %% [markdown]
# ##### Reshape input to be [samples, time steps, features]

# %%
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))

testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %% [markdown]
# ##### Create the LSTM network

# %%
model = Sequential()
model.add(LSTM(1, input_shape=(look_back, 1)))
model.add(Dense(1))

# %% [markdown]
# ##### Compile the LSTM network

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 1)                 12
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 14
# Trainable params: 14
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ##### Fit the LSTM network

# %%
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
#  - 1s - loss: 0.1349
# Epoch 2/100
#  - 1s - loss: 0.0875
# Epoch 3/100
#  - 1s - loss: 0.0582
# Epoch 4/100
#  - 1s - loss: 0.0454
# Epoch 5/100
#  - 1s - loss: 0.0396
# Epoch 6/100
#  - 1s - loss: 0.0367
# Epoch 7/100
#  - 1s - loss: 0.0340
# Epoch 8/100
#  - 1s - loss: 0.0315
# Epoch 9/100
#  - 1s - loss: 0.0289
# Epoch 10/100
#  - 1s - loss: 0.0263
# Epoch 11/100
#  - 1s - loss: 0.0237
# Epoch 12/100
#  - 1s - loss: 0.0211
# Epoch 13/100
#  - 1s - loss: 0.0188
# Epoch 14/100
#  - 1s - loss: 0.0167
# Epoch 15/100
#  - 1s - loss: 0.0149
# Epoch 16/100
#  - 1s - loss: 0.0135
# Epoch 17/100
#  - 1s - loss: 0.0125
# Epoch 18/100
#  - 1s - loss: 0.0115
# Epoch 19/100
#  - 1s - loss: 0.0110
# Epoch 20/100
#  - 1s - loss: 0.0109
# Epoch 21/100
#  - 1s - loss: 0.0104
# Epoch 22/100
#  - 1s - loss: 0.0104
# Epoch 23/100
#  - 1s - loss: 0.0103
# Epoch 24/100
#  - 1s - loss: 0.0103
# Epoch 25/100
#  - 1s - loss: 0.0102
# Epoch 26/100
#  - 1s - loss: 0.0101
# Epoch 27/100
#  - 1s - loss: 0.0102
# Epoch 28/100
#  - 1s - loss: 0.0100
# Epoch 29/100
#  - 1s - loss: 0.0100
# Epoch 30/100
#  - 1s - loss: 0.0099
# Epoch 31/100
#  - 1s - loss: 0.0099
# Epoch 32/100
#  - 1s - loss: 0.0100
# Epoch 33/100
#  - 1s - loss: 0.0098
# Epoch 34/100
#  - 1s - loss: 0.0099
# Epoch 35/100
#  - 1s - loss: 0.0100
# Epoch 36/100
#  - 1s - loss: 0.0100
# Epoch 37/100
#  - 1s - loss: 0.0098
# Epoch 38/100
#  - 1s - loss: 0.0098
# Epoch 39/100
#  - 1s - loss: 0.0098
# Epoch 40/100
#  - 1s - loss: 0.0098
# Epoch 41/100
#  - 1s - loss: 0.0098
# Epoch 42/100
#  - 1s - loss: 0.0099
# Epoch 43/100
#  - 1s - loss: 0.0097
# Epoch 44/100
#  - 1s - loss: 0.0097
# Epoch 45/100
#  - 1s - loss: 0.0097
# Epoch 46/100
#  - 1s - loss: 0.0098
# Epoch 47/100
#  - 1s - loss: 0.0096
# Epoch 48/100
#  - 1s - loss: 0.0098
# Epoch 49/100
#  - 1s - loss: 0.0097
# Epoch 50/100
#  - 1s - loss: 0.0097
# Epoch 51/100
#  - 1s - loss: 0.0097
# Epoch 52/100
#  - 1s - loss: 0.0096
# Epoch 53/100
#  - 1s - loss: 0.0097
# Epoch 54/100
#  - 1s - loss: 0.0096
# Epoch 55/100
#  - 1s - loss: 0.0096
# Epoch 56/100
#  - 1s - loss: 0.0097
# Epoch 57/100
#  - 1s - loss: 0.0095
# Epoch 58/100
#  - 1s - loss: 0.0095
# Epoch 59/100
#  - 1s - loss: 0.0096
# Epoch 60/100
#  - 1s - loss: 0.0098
# Epoch 61/100
#  - 1s - loss: 0.0094
# Epoch 62/100
#  - 1s - loss: 0.0095
# Epoch 63/100
#  - 1s - loss: 0.0094
# Epoch 64/100
#  - 1s - loss: 0.0097
# Epoch 65/100
#  - 1s - loss: 0.0093
# Epoch 66/100
#  - 1s - loss: 0.0094
# Epoch 67/100
#  - 1s - loss: 0.0094
# Epoch 68/100
#  - 1s - loss: 0.0094
# Epoch 69/100
#  - 1s - loss: 0.0094
# Epoch 70/100
#  - 1s - loss: 0.0094
# Epoch 71/100
#  - 1s - loss: 0.0095
# Epoch 72/100
#  - 1s - loss: 0.0094
# Epoch 73/100
#  - 1s - loss: 0.0095
# Epoch 74/100
#  - 1s - loss: 0.0094
# Epoch 75/100
#  - 1s - loss: 0.0094
# Epoch 76/100
#  - 1s - loss: 0.0093
# Epoch 77/100
#  - 1s - loss: 0.0093
# Epoch 78/100
#  - 1s - loss: 0.0093
# Epoch 79/100
#  - 1s - loss: 0.0093
# Epoch 80/100
#  - 1s - loss: 0.0094
# Epoch 81/100
#  - 1s - loss: 0.0093
# Epoch 82/100
#  - 1s - loss: 0.0093
# Epoch 83/100
#  - 1s - loss: 0.0093
# Epoch 84/100
#  - 1s - loss: 0.0092
# Epoch 85/100
#  - 1s - loss: 0.0092
# Epoch 86/100
#  - 1s - loss: 0.0094
# Epoch 87/100
#  - 1s - loss: 0.0093
# Epoch 88/100
#  - 1s - loss: 0.0093
# Epoch 89/100
#  - 1s - loss: 0.0093
# Epoch 90/100
#  - 1s - loss: 0.0094
# Epoch 91/100
#  - 1s - loss: 0.0093
# Epoch 92/100
#  - 1s - loss: 0.0092
# Epoch 93/100
#  - 1s - loss: 0.0094
# Epoch 94/100
#  - 1s - loss: 0.0093
# Epoch 95/100
#  - 1s - loss: 0.0092
# Epoch 96/100
#  - 1s - loss: 0.0094
# Epoch 97/100
#  - 1s - loss: 0.0092
# Epoch 98/100
#  - 1s - loss: 0.0091
# Epoch 99/100
#  - 1s - loss: 0.0091
# Epoch 100/100
#  - 1s - loss: 0.0092

# %% [markdown]
# ##### Estimate the performance of the model

# %%
# Estimate model performance
trainScore = model.evaluate(trainX, trainY, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = model.evaluate(testX, testY, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 0.01 MSE (0.09 RMSE)
# Test Score: 0.11 MSE (0.34 RMSE)

# %% [markdown]
# ##### Predictions using the built model

# %%
trainPredict_Scal = model.predict(trainX)
testPredict_Scal = model.predict(testX)

# %% [markdown]
# ##### Invert the predictions back to same units as the original data

# %%
trainPredict = scaler.inverse_transform(trainPredict_Scal)

testPredict = scaler.inverse_transform(testPredict_Scal)

# %% [markdown]
# #### Preparte and plot the data

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[:len(trainPredict), :] = trainPredict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict):, :] = testPredict

# %%
# %matplotlib notebook

# plot baseline and predictions
plt.plot(dataset)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Reference
#
#     https://keras.io/
#     http://machinelearningmastery.com
#     http://scikit-learn.org/stable/modules/classes.html
