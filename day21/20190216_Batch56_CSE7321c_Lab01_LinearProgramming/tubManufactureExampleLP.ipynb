# %% [markdown]
# ## _Decision variables : Represent the solution for the problem_
#
#
# *  X1: Number of units of Aqua-Spa produced.
# *   X2: Number of units of Hydro-Lux produced.
#
#
# ### _Objective Function_
#
# *  Z : 350 X1 + 300 X2 (Maximize)
#
# ### _Constraints_
#
# * 1 X1 + 1 X2 <= 200
# * 9 X1 + 6 X2 <= 1566
# *  12 X1 +16 X2 <= 2880
#
# ### _Non negativity restriction_
#
# *   X1 >= 0
# *   X2 >= 0

# %%
import numpy as np
from scipy.optimize import linprog
from numpy.linalg import solve

# %% [raw]
# ########################
# ###Scenario 1
# ########################
# ##LABOR_HOURS_TYPE1 = 9;
# ##LABOR_HOURS_TYPE2 = 6;
# ##PROFIT_UNIT_TYPE1 = 350;
# ##PROFIT_UNIT_TYPE2 = 300;
# ##TUBING_FEET_TYPE1 = 12;
# ##TUBING_FEET_TYPE2 = 16;
# ####
# ##MAX_TOTAL_TUBES = 200;
# ##MAX_LABOR_HOURS = 1566;
# ##MAX_TUBING = 2880 ;
# ########################
#
# ###Scenario 2 : Tubing values interchanged, others same
# ########################
# ##LABOR_HOURS_TYPE1 = 9;
# ##LABOR_HOURS_TYPE2 = 6;
# ##PROFIT_UNIT_TYPE1 = 350;
# ##PROFIT_UNIT_TYPE2 = 300;
# ##TUBING_FEET_TYPE1 = 16;
# ##TUBING_FEET_TYPE2 = 12;
# ####
# ##MAX_TOTAL_TUBES = 200;
# ##MAX_LABOR_HOURS = 1566;
# ##MAX_TUBING = 2880 ;
# ########################
#
# ##Scenario 3 : Both labor hours and tubing interchanged
# ##             Type 1 is more profitable, involves less material and labor
# #######################
# ##LABOR_HOURS_TYPE1 = 6;
# ##LABOR_HOURS_TYPE2 = 9;
# ##PROFIT_UNIT_TYPE1 = 350;
# ##PROFIT_UNIT_TYPE2 = 300;
# ##TUBING_FEET_TYPE1 = 12;
# ##TUBING_FEET_TYPE2 = 16;
# ####
# ##MAX_TOTAL_TUBES = 200;
# ##MAX_LABOR_HOURS = 1566;
# ##MAX_TUBING = 2880 ;
# #######################
#
# ###Scenario 4 :
# ###Type 1 more profitable but consumes more labor and significantly more material, also available labor hours = 1700
# ########################
# ##LABOR_HOURS_TYPE1 = 9;
# ##LABOR_HOURS_TYPE2 = 6;
# ##PROFIT_UNIT_TYPE1 = 350;
# ##PROFIT_UNIT_TYPE2 = 300;
# ##TUBING_FEET_TYPE1 = 36;
# ##TUBING_FEET_TYPE2 = 16;
# ####
# ##MAX_TOTAL_TUBES = 200;
# ##MAX_LABOR_HOURS = 1700;
# ##MAX_TUBING = 2880 ;
# #
# ########################
#
# ###Scenario 5 :
# ###Labor and tubing interchanged, total labor hours = 1700
# ###Type 1 more profitable,  consumes less labor but more material than Type 2.
# ########################
# #LABOR_HOURS_TYPE1 = 6;
# #LABOR_HOURS_TYPE2 = 9;
# #PROFIT_UNIT_TYPE1 = 350;
# #PROFIT_UNIT_TYPE2 = 300;
# #TUBING_FEET_TYPE1 = 16;
# #TUBING_FEET_TYPE2 = 12;
# ###
# #MAX_TOTAL_TUBES = 200;
# #MAX_LABOR_HOURS = 1700;
# #MAX_TUBING = 2880 ;
# #
# #######################
#
# ##Scenario 6 :
# ##Tubing interchanged :
# ##Type 1 more profitable,  consumes more labor and more material than Type 2, also available labor hours = 1700
# #######################
# #LABOR_HOURS_TYPE1 = 9;
# #LABOR_HOURS_TYPE2 = 6;
# #PROFIT_UNIT_TYPE1 = 350;
# #PROFIT_UNIT_TYPE2 = 300;
# #TUBING_FEET_TYPE1 = 16;
# #TUBING_FEET_TYPE2 = 12;
# ##
# #MAX_TOTAL_TUBES = 200;
# #MAX_LABOR_HOURS = 1700;
# #MAX_TUBING = 2880 ;
#
# #######################
#
# ##Scenario 7 :
# ##All other values unchanged as compared to the original, only labor hours changed to 1700.
# #######################

# %%
LABOR_HOURS_TYPE1 = 9;
LABOR_HOURS_TYPE2 = 6;
PROFIT_UNIT_TYPE1 = 350;
PROFIT_UNIT_TYPE2 = 300;
TUBING_FEET_TYPE1 = 12;
TUBING_FEET_TYPE2 = 16;



MAX_TOTAL_TUBES = 200;
MAX_LABOR_HOURS = 1700;
MAX_TUBING = 2880 ;

# Solve the resulting Linear Program
f = np.array([-PROFIT_UNIT_TYPE1,-PROFIT_UNIT_TYPE2]); #Objective function
    # maximize PROFIT_UNIT_TYPE1*x1 + PROFIT_UNIT_TYPE2*x2
    # equivalent to minimize -PROFIT_UNIT_TYPE1*x1 - PROFIT_UNIT_TYPE2*x2
    
    
A_ineq = np.array([[1,1],[LABOR_HOURS_TYPE1,LABOR_HOURS_TYPE2],[TUBING_FEET_TYPE1,TUBING_FEET_TYPE2]]);
b_ineq = np.array([MAX_TOTAL_TUBES,MAX_LABOR_HOURS,MAX_TUBING]);

lb_ub = (0,None);

res = linprog(f, A_ub=A_ineq, b_ub=b_ineq,bounds=lb_ub);

maxProfit = -res.fun; # Since we minimize the negative 


print("Max value of objective = ",maxProfit);
print(' Solution x = ', res.x);
# Out:
# Max value of objective =  68333.33333333333
#  Solution x =  [166.66666667  33.33333333]
