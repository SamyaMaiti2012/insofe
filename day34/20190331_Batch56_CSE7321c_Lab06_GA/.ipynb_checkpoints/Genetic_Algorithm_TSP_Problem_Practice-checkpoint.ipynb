# %% [markdown]
# ## Import libraries

# %%
import os 
import csv
import numpy as np
import pandas as pd
import random # library to generate random numbers
np.random.seed(seed=42)
import math

# %% [markdown]
# #### Import data

# %%
data1 = pd.read_csv("cities_and_distances.csv",header=0,index_col=0)
data1
# Out:
#            Bangalore  Jaipur  Varanasi  Udaipur  Delhi  Chennai  Mysore  Agra  \
# Bangalore          0    2026      1825     1724   2166      346     149  1923
# Jaipur          2026       0       849      393    287     2108    2121   240
# Varanasi        1825     849         0     1154    834     1862    1976   614
# Udaipur         1724     393      1154        0    661     2077    1809   634
# Delhi           2166     287       834      661      0     2203    2317   233
# Chennai          346    2108      1862     2077   2203        0     482  1957
# Mysore           149    2121      1976     1809   2317      482       0  2072
# Agra            1923     240       614      634    233     1957    2072     0
# Kolkata         1862    1520       683     1825   1498     1669    2012  1280
# Mumbai           980    1146      1524      753   1415     1345    1064  1323
# Hyderabad        569    1483      1237     1349   1578      627     718  1334
#
#            Kolkata  Mumbai  Hyderabad
# Bangalore     1862     980        569
# Jaipur        1520    1146       1483
# Varanasi       683    1524       1237
# Udaipur       1825     753       1349
# Delhi         1498    1415       1578
# Chennai       1669    1345        627
# Mysore        2012    1064        718
# Agra          1280    1323       1334
# Kolkata          0    2053       1493
# Mumbai        2053       0        711
# Hyderabad     1493     711          0

# %% [markdown]
# #### Starting Point is Bangalore

# %%
starting_point = "Bangalore"

# %%
data1.columns
# Out:
# Index(['Bangalore', 'Jaipur', 'Varanasi', 'Udaipur', 'Delhi', 'Chennai',
#        'Mysore', 'Agra', 'Kolkata', 'Mumbai', 'Hyderabad'],
#       dtype='object')

# %%
data1.shape
# Out:
# (11, 11)

# %% [markdown]
# ###### The number of possible solutions are: 10! = 3628800
# We can generate all possible solutions and try to find the best of those , but this is a time taking process and may not be feasible for big problems.
# Genetic algorithm approach takes a randominzed search approach to find the best solution, with enough number of iterations, mutation and cross over, GA can reach the global minima for most of the problems.

# %% [markdown]
# ##### Map places to integers

# %%
cities_mapping = {}

for i in enumerate(data1.columns):
    cities_mapping[i[0]] = i[1]
    print(i[0])
    # print(i[1])
    print(cities_mapping[i[0]])
        
print("\n")
print(cities_mapping)
print(type(cities_mapping))
# Out:
# 0
# Bangalore
# 1
# Jaipur
# 2
# Varanasi
# 3
# Udaipur
# 4
# Delhi
# 5
# Chennai
# 6
# Mysore
# 7
# Agra
# 8
# Kolkata
# 9
# Mumbai
# 10
# Hyderabad
#
#
# {0: 'Bangalore', 1: 'Jaipur', 2: 'Varanasi', 3: 'Udaipur', 4: 'Delhi', 5: 'Chennai', 6: 'Mysore', 7: 'Agra', 8: 'Kolkata', 9: 'Mumbai', 10: 'Hyderabad'}
# <class 'dict'>

# %%
one_route = [5,6,10,9,1,3,4,7,2,8] # one of the routes

# %%
one_route
# Out:
# [5, 6, 10, 9, 1, 3, 4, 7, 2, 8]

# %% [markdown]
# ## createRandomRoute:: this function is to generate random route

# %% [raw]
# sample() is an inbuilt function of random module in Python that returns a particular length list of items chosen from the sequence i.e. list, tuple, string or set. Used for random sampling without replacement.

# %%
def createRandomRoute():
    """ This function generates a route by sampling numbers """
    my_randoms = random.sample(range(1,11), 10)    # excluding 0 from the range as 0 is the starting point for us i.e. Bangalore
    return my_randoms

# %%
temp_route = createRandomRoute()

# %%
temp_route
# Out:
# [5, 4, 8, 9, 1, 3, 10, 7, 6, 2]

# %%
len(temp_route)
# Out:
# 10

# %%
data1.iloc[0, temp_route[0]]
# Out:
# 346

# %% [markdown]
# ## fitnessFunction :: Function to compute the route cost using the already defined path

# %%
def fitnessFunction(pvRouteMap):
    """This functions takes the route generated and returns the cost incurred."""
    traverseData    = data1.copy() # creating a copy of the original dataframe
    sourcePoint     = 0 # defining a starting point
    stopsCovered    = 0 # setting the number of stops covered to 0
    routeCost       = 0 # setting the initial cost to 0
    pvRouteMap1 = pvRouteMap #+ [pvRouteMap[0]]
    
    # initiate a while loop and calculate the cost for the whole path traversed and return the cost
    while(stopsCovered < len(pvRouteMap1)) :  
        routeCost = routeCost + traverseData.iloc[sourcePoint, pvRouteMap1[stopsCovered]]          
        
        print("routeCost+", sourcePoint, "->",pvRouteMap1[stopsCovered], routeCost)
        print("\n")
        
        """route cost is the sum of the cost incurred from travelling from one point to the next according
        to the route that was generated previously."""
        
        sourcePoint = pvRouteMap1[stopsCovered] # update the source point to the next point in the route
        stopsCovered = stopsCovered+1 #Adding 1 to the stops covered
#         print(sourcePoint)
    routeCost = routeCost + traverseData.iloc[pvRouteMap1[-1],0]

    return(routeCost)

# %%
fitnessFunction(temp_route)
# Out:
# routeCost+ 0 -> 5 346
#
#
# routeCost+ 5 -> 4 2549
#
#
# routeCost+ 4 -> 8 4047
#
#
# routeCost+ 8 -> 9 6100
#
#
# routeCost+ 9 -> 1 7246
#
#
# routeCost+ 1 -> 3 7639
#
#
# routeCost+ 3 -> 10 8988
#
#
# routeCost+ 10 -> 7 10322
#
#
# routeCost+ 7 -> 6 12394
#
#
# routeCost+ 6 -> 2 14370
# 16195

# %% [markdown]
# #### We can look at the positions and think of one good route, we will see if our algorithm performs better than this route

# %%
print(one_route)
# Out:
# [5, 6, 10, 9, 1, 3, 4, 7, 2, 8]

# %%
one_route_cities = []

for i in one_route:
    one_route_cities.append(cities_mapping[i])
    
one_route_cities
# Out:
# ['Chennai',
#  'Mysore',
#  'Hyderabad',
#  'Mumbai',
#  'Jaipur',
#  'Udaipur',
#  'Delhi',
#  'Agra',
#  'Varanasi',
#  'Kolkata']

# %%
fitnessFunction(one_route)
# Out:
# routeCost+ 0 -> 5 346
#
#
# routeCost+ 5 -> 6 828
#
#
# routeCost+ 6 -> 10 1546
#
#
# routeCost+ 10 -> 9 2257
#
#
# routeCost+ 9 -> 1 3403
#
#
# routeCost+ 1 -> 3 3796
#
#
# routeCost+ 3 -> 4 4457
#
#
# routeCost+ 4 -> 7 4690
#
#
# routeCost+ 7 -> 2 5304
#
#
# routeCost+ 2 -> 8 5987
# 7849

# %% [markdown]
# ##  mutateRoute:: this function will generate mutated path where we define mutation policy

# %%
def mutateRoute(initPath, mutateFactor):
    """ This functions generates a mutated path, takes an input path and returns a mutated path.
    Mutate factor is the point at which the string(route here) is split and the two parts are swapped."""

    temp1 = initPath[0:mutateFactor]
    print(temp1)
    temp2 = initPath[mutateFactor:len(initPath)]
    print(temp2)
    newPath = temp2 + temp1
    print(newPath)
    return(newPath)

# %% [markdown]
# #### Generate a sample path and mutate that path

# %%
temp_route = createRandomRoute()

# %%
temp_route
# Out:
# [1, 4, 10, 7, 3, 6, 5, 8, 2, 9]

# %%
mutateRoute(temp_route,2)
# Out:
# [1, 4]
# [10, 7, 3, 6, 5, 8, 2, 9]
# [10, 7, 3, 6, 5, 8, 2, 9, 1, 4]
# [10, 7, 3, 6, 5, 8, 2, 9, 1, 4]

# %%
fitnessFunction(temp_route)
# Out:
# 13308

# %%
print("Total distance travelled to cover the route of {} is {}".format(" => ".join( one_route_cities ),fitnessFunction(one_route)))
# Out:
# Total distance travelled to cover the route of Chennai => Mysore => Hyderabad => Mumbai => Jaipur => Udaipur => Delhi => Agra => Varanasi => Kolkata is 7849

# %% [markdown]
# # Function to create Initial (random) Population

# %%
def initialPopCost(ninitpop = 10):
    """This function generates new routes and calculates the cost of the route.
    returns a dictionary of routes and the cost."""
    np.random.seed(seed=42)
    intial_cost = 0
    routeCost = []
    routes = [createRandomRoute() for i in range(0, ninitpop)]
    routes_Cost = [fitnessFunction(i) for i in routes]
    routes_DF = pd.DataFrame([routes,routes_Cost]).transpose()
    routes_DF.columns = ['Route','Cost']
    return(routes_DF)

# %%
initial_pop_cost = initialPopCost(10)
initial_pop_cost
# Out:
#                              Route   Cost
# 0  [4, 5, 3, 1, 6, 9, 2, 10, 8, 7]  17481
# 1  [2, 10, 9, 5, 6, 4, 1, 7, 8, 3]  13273
# 2  [3, 7, 6, 5, 1, 2, 8, 4, 10, 9]  13319
# 3  [7, 10, 6, 2, 1, 9, 3, 4, 8, 5]  12873
# 4  [2, 3, 5, 1, 10, 4, 8, 9, 7, 6]  17320
# 5  [7, 10, 1, 4, 8, 9, 5, 3, 6, 2]  17610
# 6  [1, 2, 8, 6, 7, 3, 9, 10, 5, 4]  14736
# 7  [4, 7, 3, 10, 5, 2, 8, 9, 1, 6]  13023
# 8  [4, 3, 2, 7, 6, 9, 5, 8, 10, 1]  15747
# 9  [3, 2, 6, 7, 5, 9, 8, 10, 1, 4]  17710

# %%
sorted_init_pop = initial_pop_cost.sort_values(['Cost'])
sorted_init_pop
# Out:
#                              Route   Cost
# 3  [7, 10, 6, 2, 1, 9, 3, 4, 8, 5]  12873
# 7  [4, 7, 3, 10, 5, 2, 8, 9, 1, 6]  13023
# 1  [2, 10, 9, 5, 6, 4, 1, 7, 8, 3]  13273
# 2  [3, 7, 6, 5, 1, 2, 8, 4, 10, 9]  13319
# 6  [1, 2, 8, 6, 7, 3, 9, 10, 5, 4]  14736
# 8  [4, 3, 2, 7, 6, 9, 5, 8, 10, 1]  15747
# 4  [2, 3, 5, 1, 10, 4, 8, 9, 7, 6]  17320
# 0  [4, 5, 3, 1, 6, 9, 2, 10, 8, 7]  17481
# 5  [7, 10, 1, 4, 8, 9, 5, 3, 6, 2]  17610
# 9  [3, 2, 6, 7, 5, 9, 8, 10, 1, 4]  17710

# %% [markdown]
# ## Partially Mapped Crossover

# %% [markdown]
# ###### - implemented PMX conceptualized by goldberg

# %%
def crossOverFunction(parent1, parent2,crossover_factor_start_pos=2,
                             crossover_factor_end_pos=6):
    
    indexes_for_crossover = random.sample(set(range(len(p1))), 2)
    
    crossover_factor_start_pos,crossover_factor_end_pos = min(indexes_for_crossover),max(indexes_for_crossover)
    print("Start"," End")
    print (crossover_factor_start_pos,"     ", crossover_factor_end_pos)
    
    ## generate child 1
    child1 = parent1[0:crossover_factor_start_pos]+\
    parent2[crossover_factor_start_pos:crossover_factor_end_pos] +\
    parent1[crossover_factor_end_pos:]
    # print(child1)
    # print("\n")
    
    ## generate child 2
    child2 = parent2[0:crossover_factor_start_pos] +\
    parent1[crossover_factor_start_pos:crossover_factor_end_pos] +\
    parent2[crossover_factor_end_pos:]
    
    # print(child2)
        
    ## Create mappings
    mapping = list(zip(parent1[crossover_factor_start_pos:crossover_factor_end_pos], # create tuple of mappings
                      parent2[crossover_factor_start_pos:crossover_factor_end_pos]))
    print("\n")
    print("Mapping")
    print(mapping)
    print("\n")
    
    # run until all the nodes in the route are unique
    while len(np.unique(child1)) != len(child1):
        child1_part = child1[:crossover_factor_start_pos]+child1[crossover_factor_end_pos:]
        
        # print(child1_part)
        # print("\n")
        for i in child1_part:
            for j in mapping:
                if i == j[1]: # j[1] - Parent 2 window elements                 
                    child1_part[child1_part.index(i)] = j[0] # j[0] - Parent 1 window elements
                    
        child1 = child1_part[:crossover_factor_start_pos]+ child1[crossover_factor_start_pos:crossover_factor_end_pos]+ child1_part[crossover_factor_start_pos:]
        
        print("Child1 Intermediate {}".format(child1))
    print("\n")
        
    # run until all the nodes in the route are unique
    while len(np.unique(child2)) != len(child2):
        child2_part = child2[:crossover_factor_start_pos]+child2[crossover_factor_end_pos:]
        # print(child2_part)
        for i in child2_part:
            for j in mapping:
                if i == j[0]:
                    child2_part[child2_part.index(i)] = j[1]
        child2 = child2_part[:crossover_factor_start_pos]+ child2[crossover_factor_start_pos:crossover_factor_end_pos]+ child2_part[crossover_factor_start_pos:]
        
        print("Child2 Intermediate {}".format(child2))
        
    return( child1,child2)

# %%
p1 = [5,7,2,4,8,9,3,6,1]

# %%
p2 = [8,6,9,3,2,5,1,7,4]

# %%
print(p1)
print(p2)
# Out:
# [5, 7, 2, 4, 8, 9, 3, 6, 1]
# [8, 6, 9, 3, 2, 5, 1, 7, 4]

# %%
for i in zip([p1,p2],crossOverFunction(p1,p2)):
    print ("\nParent: {}  : Child: {}".format(i[0],i[1]))
# Out:
# Start  End
# 0       5
#
#
# Mapping
# [(5, 8), (7, 6), (2, 9), (4, 3), (8, 2)]
#
#
# Child1 Intermediate [8, 6, 9, 3, 2, 2, 4, 7, 1]
# Child1 Intermediate [8, 6, 9, 3, 2, 8, 4, 7, 1]
# Child1 Intermediate [8, 6, 9, 3, 2, 5, 4, 7, 1]
#
#
# Child2 Intermediate [5, 7, 2, 4, 8, 8, 1, 6, 3]
# Child2 Intermediate [5, 7, 2, 4, 8, 2, 1, 6, 3]
# Child2 Intermediate [5, 7, 2, 4, 8, 9, 1, 6, 3]
#
# Parent: [5, 7, 2, 4, 8, 9, 3, 6, 1]  : Child: [8, 6, 9, 3, 2, 5, 4, 7, 1]
#
# Parent: [8, 6, 9, 3, 2, 5, 1, 7, 4]  : Child: [5, 7, 2, 4, 8, 9, 1, 6, 3]

# %% [markdown]
#  ### Best Solution So Far

# %% [markdown]
# Total distance travelled to cover the final route of
#  Bangalore => Chennai => Hyderabad => Kolkata => Varanasi => Delhi => Agra => Jaipur => Udaipur => Mumbai => Mysore => Bangalore is 6815

# %%
def genetic_algorithm(sorted_current_generation, no_of_chromosomes = 10, mutation_factor=0.2, xover_factor = 0.3):

    
    nextgen_child = [] 
    
    xover_pool = int(round(no_of_chromosomes * xover_factor ))
    print("xover_pool=",xover_pool)
    
    no_of_loops = int((no_of_chromosomes // 2) )
    
    print('starting crossover')
    
    for i in range(0,no_of_loops):
        
        # print("sorted_current_generation")
        # print(sorted_current_generation)
        
        parent_index1 = random.choice(range(0,xover_pool))
        p1= sorted_current_generation.iloc[parent_index1,0]
        
        print("p1")
        print(p1)
        
        print("\n")
        
        parent_index2 = random.choice(range(0,xover_pool))
        p2= sorted_current_generation.iloc[parent_index2,0]
        
        print("p2")
        print(p2)
        
        c1, c2 = crossOverFunction(p1,p2)
        
        print("c1")
        print(c1)
        print("\n")
        print("c2")
        print(c2)
        print("\n")
        nextgen_child.extend([c1,c2])
    
    print("\n")
    print("nextgen_child")
    print(nextgen_child)
        
    nextgen_costs = [fitnessFunction(i) for i in nextgen_child]
    next_generation = pd.DataFrame([nextgen_child,nextgen_costs],).transpose() 
    next_generation.columns = ['Route','Cost']
    
    print("next_generation")
    print(next_generation)
    
    
    print('starting Mutation')
    
    for i in range(0, no_of_chromosomes) :
        mutation_prob = random.random() # using random() function to generate a random number between 0 and 1
        
        if mutation_prob < mutation_factor: 
            mutated_child = mutateRoute(next_generation.iloc[i,0] , 2)
            
            next_generation.iloc[i,0] = mutated_child
            
            # print("mutated_child")
            # print(next_generation.iloc[i,0])
            
            # print("\n")
            next_generation.iloc[i,1] = fitnessFunction(next_generation.iloc[i,0])
            
            # print("next_generation.iloc[i,1]")
            # print(next_generation.iloc[i,1])

    return (next_generation)

# %%
def perform_genetic_algorithm(no_of_iterations = 6, no_of_chromosomes = 10, mutation_factor=0.2, xover_factor = 0.3):
    best_solution = []
    best_cost = 99999
    current_generation = initialPopCost(no_of_chromosomes)
    sorted_current_generation = current_generation.sort_values('Cost')
    
    for i in range(0, no_of_iterations) :
        next_generation = genetic_algorithm(sorted_current_generation,no_of_chromosomes, mutation_factor, xover_factor)
        sorted_next_generation = next_generation.sort_values('Cost')
        
        print ("Completed {} runs of GA.".format(i + 1))
        print ("Below are the best chromosomes:")
        
        print(sorted_next_generation.head(2))

        print("\n")
        sorted_current_generation = sorted_next_generation
        if best_cost > sorted_next_generation.iloc[0,1] :
            best_cost = sorted_next_generation.iloc[0,1]
            best_solution = sorted_next_generation.iloc[0,0]
            print("best_solution")
            print(best_solution)
        
        final_route = []
        for i in best_solution:
            final_route.append(cities_mapping[i])
        final_route = [starting_point] + final_route + [starting_point]
        print("Total distance travelled to cover the final route of \n {} is {}".format(" => ".join(final_route),best_cost))

    return (best_solution, best_cost)

# %%
best_solution, best_cost = perform_genetic_algorithm()
# Out:
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 5 4134
#
#
# routeCost+ 5 -> 9 5479
#
#
# routeCost+ 9 -> 2 7003
#
#
# routeCost+ 2 -> 4 7837
#
#
# routeCost+ 4 -> 3 8498
#
#
# routeCost+ 3 -> 7 9132
#
#
# routeCost+ 7 -> 6 11204
#
#
# routeCost+ 6 -> 10 11922
#
#
# routeCost+ 10 -> 8 13415
#
#
# routeCost+ 0 -> 3 1724
#
#
# routeCost+ 3 -> 7 2358
#
#
# routeCost+ 7 -> 9 3681
#
#
# routeCost+ 9 -> 4 5096
#
#
# routeCost+ 4 -> 6 7413
#
#
# routeCost+ 6 -> 1 9534
#
#
# routeCost+ 1 -> 5 11642
#
#
# routeCost+ 5 -> 10 12269
#
#
# routeCost+ 10 -> 2 13506
#
#
# routeCost+ 2 -> 8 14189
#
#
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 8 4804
#
#
# routeCost+ 8 -> 5 6473
#
#
# routeCost+ 5 -> 10 7100
#
#
# routeCost+ 10 -> 9 7811
#
#
# routeCost+ 9 -> 7 9134
#
#
# routeCost+ 7 -> 4 9367
#
#
# routeCost+ 4 -> 1 9654
#
#
# routeCost+ 1 -> 6 11775
#
#
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 3 2419
#
#
# routeCost+ 3 -> 4 3080
#
#
# routeCost+ 4 -> 8 4578
#
#
# routeCost+ 8 -> 9 6631
#
#
# routeCost+ 9 -> 10 7342
#
#
# routeCost+ 10 -> 2 8579
#
#
# routeCost+ 2 -> 6 10555
#
#
# routeCost+ 6 -> 5 11037
#
#
# routeCost+ 5 -> 7 12994
#
#
# routeCost+ 0 -> 6 149
#
#
# routeCost+ 6 -> 2 2125
#
#
# routeCost+ 2 -> 4 2959
#
#
# routeCost+ 4 -> 9 4374
#
#
# routeCost+ 9 -> 10 5085
#
#
# routeCost+ 10 -> 7 6419
#
#
# routeCost+ 7 -> 1 6659
#
#
# routeCost+ 1 -> 8 8179
#
#
# routeCost+ 8 -> 3 10004
#
#
# routeCost+ 3 -> 5 12081
#
#
# routeCost+ 0 -> 5 346
#
#
# routeCost+ 5 -> 2 2208
#
#
# routeCost+ 2 -> 3 3362
#
#
# routeCost+ 3 -> 10 4711
#
#
# routeCost+ 10 -> 4 6289
#
#
# routeCost+ 4 -> 8 7787
#
#
# routeCost+ 8 -> 1 9307
#
#
# routeCost+ 1 -> 7 9547
#
#
# routeCost+ 7 -> 6 11619
#
#
# routeCost+ 6 -> 9 12683
#
#
# routeCost+ 0 -> 5 346
#
#
# routeCost+ 5 -> 2 2208
#
#
# routeCost+ 2 -> 10 3445
#
#
# routeCost+ 10 -> 7 4779
#
#
# routeCost+ 7 -> 9 6102
#
#
# routeCost+ 9 -> 1 7248
#
#
# routeCost+ 1 -> 4 7535
#
#
# routeCost+ 4 -> 8 9033
#
#
# routeCost+ 8 -> 3 10858
#
#
# routeCost+ 3 -> 6 12667
#
#
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 9 3172
#
#
# routeCost+ 9 -> 4 4587
#
#
# routeCost+ 4 -> 6 6904
#
#
# routeCost+ 6 -> 8 8916
#
#
# routeCost+ 8 -> 5 10585
#
#
# routeCost+ 5 -> 10 11212
#
#
# routeCost+ 10 -> 3 12561
#
#
# routeCost+ 3 -> 2 13715
#
#
# routeCost+ 2 -> 7 14329
#
#
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 3 2419
#
#
# routeCost+ 3 -> 9 3172
#
#
# routeCost+ 9 -> 10 3883
#
#
# routeCost+ 10 -> 8 5376
#
#
# routeCost+ 8 -> 5 7045
#
#
# routeCost+ 5 -> 4 9248
#
#
# routeCost+ 4 -> 6 11565
#
#
# routeCost+ 6 -> 2 13541
#
#
# routeCost+ 2 -> 7 14155
#
#
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 3 2419
#
#
# routeCost+ 3 -> 10 3768
#
#
# routeCost+ 10 -> 8 5261
#
#
# routeCost+ 8 -> 7 6541
#
#
# routeCost+ 7 -> 2 7155
#
#
# routeCost+ 2 -> 9 8679
#
#
# routeCost+ 9 -> 4 10094
#
#
# routeCost+ 4 -> 6 12411
#
#
# routeCost+ 6 -> 5 12893
#
#
# xover_pool= 3
# starting crossover
# p1
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# p2
# [5, 2, 10, 7, 9, 1, 4, 8, 3, 6]
# Start  End
# 3       7
#
#
# Mapping
# [(5, 7), (10, 9), (9, 1), (7, 4)]
#
#
# Child1 Intermediate [2, 3, 8, 7, 9, 1, 4, 7, 9, 6]
# Child1 Intermediate [2, 3, 8, 7, 9, 1, 4, 5, 10, 6]
#
#
# Child2 Intermediate [7, 2, 9, 5, 10, 9, 7, 8, 3, 6]
# Child2 Intermediate [4, 2, 1, 5, 10, 9, 7, 8, 3, 6]
# c1
# [2, 3, 8, 7, 9, 1, 4, 5, 10, 6]
#
#
# c2
# [4, 2, 1, 5, 10, 9, 7, 8, 3, 6]
#
#
# p1
# [6, 2, 4, 9, 10, 7, 1, 8, 3, 5]
#
#
# p2
# [5, 2, 10, 7, 9, 1, 4, 8, 3, 6]
# Start  End
# 5       7
#
#
# Mapping
# [(7, 1), (1, 4)]
#
#
# Child1 Intermediate [6, 2, 1, 9, 10, 1, 4, 8, 3, 5]
# Child1 Intermediate [6, 2, 7, 9, 10, 1, 4, 8, 3, 5]
#
#
# Child2 Intermediate [5, 2, 10, 1, 9, 7, 1, 8, 3, 6]
# Child2 Intermediate [5, 2, 10, 4, 9, 7, 1, 8, 3, 6]
# c1
# [6, 2, 7, 9, 10, 1, 4, 8, 3, 5]
#
#
# c2
# [5, 2, 10, 4, 9, 7, 1, 8, 3, 6]
#
#
# p1
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# p2
# [5, 2, 10, 7, 9, 1, 4, 8, 3, 6]
# Start  End
# 4       7
#
#
# Mapping
# [(10, 9), (9, 1), (7, 4)]
#
#
# Child1 Intermediate [2, 3, 8, 5, 9, 1, 4, 7, 9, 6]
# Child1 Intermediate [2, 3, 8, 5, 9, 1, 4, 7, 10, 6]
#
#
# Child2 Intermediate [5, 2, 9, 4, 10, 9, 7, 8, 3, 6]
# Child2 Intermediate [5, 2, 1, 4, 10, 9, 7, 8, 3, 6]
# c1
# [2, 3, 8, 5, 9, 1, 4, 7, 10, 6]
#
#
# c2
# [5, 2, 1, 4, 10, 9, 7, 8, 3, 6]
#
#
# p1
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# p2
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
# Start  End
# 5       7
#
#
# Mapping
# [(9, 9), (7, 7)]
#
#
#
#
# c1
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# c2
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# p1
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# p2
# [5, 2, 10, 7, 9, 1, 4, 8, 3, 6]
# Start  End
# 3       8
#
#
# Mapping
# [(5, 7), (10, 9), (9, 1), (7, 4), (4, 8)]
#
#
# Child1 Intermediate [2, 3, 4, 7, 9, 1, 4, 8, 9, 6]
# Child1 Intermediate [2, 3, 7, 7, 9, 1, 4, 8, 10, 6]
# Child1 Intermediate [2, 3, 5, 7, 9, 1, 4, 8, 10, 6]
#
#
# Child2 Intermediate [7, 2, 9, 5, 10, 9, 7, 4, 3, 6]
# Child2 Intermediate [4, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Child2 Intermediate [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# c1
# [2, 3, 5, 7, 9, 1, 4, 8, 10, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
#
#
# nextgen_child
# [[2, 3, 8, 7, 9, 1, 4, 5, 10, 6], [4, 2, 1, 5, 10, 9, 7, 8, 3, 6], [6, 2, 7, 9, 10, 1, 4, 8, 3, 5], [5, 2, 10, 4, 9, 7, 1, 8, 3, 6], [2, 3, 8, 5, 9, 1, 4, 7, 10, 6], [5, 2, 1, 4, 10, 9, 7, 8, 3, 6], [2, 3, 8, 5, 10, 9, 7, 4, 1, 6], [2, 3, 8, 5, 10, 9, 7, 4, 1, 6], [2, 3, 5, 7, 9, 1, 4, 8, 10, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]]
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 8 4804
#
#
# routeCost+ 8 -> 7 6084
#
#
# routeCost+ 7 -> 9 7407
#
#
# routeCost+ 9 -> 1 8553
#
#
# routeCost+ 1 -> 4 8840
#
#
# routeCost+ 4 -> 5 11043
#
#
# routeCost+ 5 -> 10 11670
#
#
# routeCost+ 10 -> 6 12388
#
#
# routeCost+ 0 -> 4 2166
#
#
# routeCost+ 4 -> 2 3000
#
#
# routeCost+ 2 -> 1 3849
#
#
# routeCost+ 1 -> 5 5957
#
#
# routeCost+ 5 -> 10 6584
#
#
# routeCost+ 10 -> 9 7295
#
#
# routeCost+ 9 -> 7 8618
#
#
# routeCost+ 7 -> 8 9898
#
#
# routeCost+ 8 -> 3 11723
#
#
# routeCost+ 3 -> 6 13532
#
#
# routeCost+ 0 -> 6 149
#
#
# routeCost+ 6 -> 2 2125
#
#
# routeCost+ 2 -> 7 2739
#
#
# routeCost+ 7 -> 9 4062
#
#
# routeCost+ 9 -> 10 4773
#
#
# routeCost+ 10 -> 1 6256
#
#
# routeCost+ 1 -> 4 6543
#
#
# routeCost+ 4 -> 8 8041
#
#
# routeCost+ 8 -> 3 9866
#
#
# routeCost+ 3 -> 5 11943
#
#
# routeCost+ 0 -> 5 346
#
#
# routeCost+ 5 -> 2 2208
#
#
# routeCost+ 2 -> 10 3445
#
#
# routeCost+ 10 -> 4 5023
#
#
# routeCost+ 4 -> 9 6438
#
#
# routeCost+ 9 -> 7 7761
#
#
# routeCost+ 7 -> 1 8001
#
#
# routeCost+ 1 -> 8 9521
#
#
# routeCost+ 8 -> 3 11346
#
#
# routeCost+ 3 -> 6 13155
#
#
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 8 4804
#
#
# routeCost+ 8 -> 5 6473
#
#
# routeCost+ 5 -> 9 7818
#
#
# routeCost+ 9 -> 1 8964
#
#
# routeCost+ 1 -> 4 9251
#
#
# routeCost+ 4 -> 7 9484
#
#
# routeCost+ 7 -> 10 10818
#
#
# routeCost+ 10 -> 6 11536
#
#
# routeCost+ 0 -> 5 346
#
#
# routeCost+ 5 -> 2 2208
#
#
# routeCost+ 2 -> 1 3057
#
#
# routeCost+ 1 -> 4 3344
#
#
# routeCost+ 4 -> 10 4922
#
#
# routeCost+ 10 -> 9 5633
#
#
# routeCost+ 9 -> 7 6956
#
#
# routeCost+ 7 -> 8 8236
#
#
# routeCost+ 8 -> 3 10061
#
#
# routeCost+ 3 -> 6 11870
#
#
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 8 4804
#
#
# routeCost+ 8 -> 5 6473
#
#
# routeCost+ 5 -> 10 7100
#
#
# routeCost+ 10 -> 9 7811
#
#
# routeCost+ 9 -> 7 9134
#
#
# routeCost+ 7 -> 4 9367
#
#
# routeCost+ 4 -> 1 9654
#
#
# routeCost+ 1 -> 6 11775
#
#
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 8 4804
#
#
# routeCost+ 8 -> 5 6473
#
#
# routeCost+ 5 -> 10 7100
#
#
# routeCost+ 10 -> 9 7811
#
#
# routeCost+ 9 -> 7 9134
#
#
# routeCost+ 7 -> 4 9367
#
#
# routeCost+ 4 -> 1 9654
#
#
# routeCost+ 1 -> 6 11775
#
#
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 5 5056
#
#
# routeCost+ 5 -> 7 7013
#
#
# routeCost+ 7 -> 9 8336
#
#
# routeCost+ 9 -> 1 9482
#
#
# routeCost+ 1 -> 4 9769
#
#
# routeCost+ 4 -> 8 11267
#
#
# routeCost+ 8 -> 10 12760
#
#
# routeCost+ 10 -> 6 13478
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# next_generation
#                              Route   Cost
# 0  [2, 3, 8, 7, 9, 1, 4, 5, 10, 6]  12537
# 1  [4, 2, 1, 5, 10, 9, 7, 8, 3, 6]  13681
# 2  [6, 2, 7, 9, 10, 1, 4, 8, 3, 5]  12289
# 3  [5, 2, 10, 4, 9, 7, 1, 8, 3, 6]  13304
# 4  [2, 3, 8, 5, 9, 1, 4, 7, 10, 6]  11685
# 5  [5, 2, 1, 4, 10, 9, 7, 8, 3, 6]  12019
# 6  [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]  11924
# 7  [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]  11924
# 8  [2, 3, 5, 7, 9, 1, 4, 8, 10, 6]  13627
# 9  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# starting Mutation
# [4, 2]
# [1, 5, 10, 9, 7, 8, 3, 6]
# [1, 5, 10, 9, 7, 8, 3, 6, 4, 2]
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 5 4134
#
#
# routeCost+ 5 -> 10 4761
#
#
# routeCost+ 10 -> 9 5472
#
#
# routeCost+ 9 -> 7 6795
#
#
# routeCost+ 7 -> 8 8075
#
#
# routeCost+ 8 -> 3 9900
#
#
# routeCost+ 3 -> 6 11709
#
#
# routeCost+ 6 -> 4 14026
#
#
# routeCost+ 4 -> 2 14860
#
#
# [2, 3]
# [8, 5, 9, 1, 4, 7, 10, 6]
# [8, 5, 9, 1, 4, 7, 10, 6, 2, 3]
# routeCost+ 0 -> 8 1862
# routeCost+ 8 -> 5 3531
#
#
# routeCost+ 5 -> 9 4876
#
#
# routeCost+ 9 -> 1 6022
#
#
# routeCost+ 1 -> 4 6309
#
#
# routeCost+ 4 -> 7 6542
#
#
# routeCost+ 7 -> 10 7876
#
#
# routeCost+ 10 -> 6 8594
#
#
# routeCost+ 6 -> 2 10570
#
#
# routeCost+ 2 -> 3 11724
#
#
# Completed 1 runs of GA.
# Below are the best chromosomes:
#                              Route   Cost
# 9  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 6  [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]  11924
#
#
# best_solution
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Total distance travelled to cover the final route of
#  Bangalore => Kolkata => Varanasi => Jaipur => Chennai => Hyderabad => Mumbai => Agra => Delhi => Udaipur => Mysore => Bangalore is 11015
# xover_pool= 3
# starting crossover
# p1
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# p2
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
# Start  End
# 2       4
#
#
# Mapping
# [(8, 8), (5, 5)]
#
#
#
#
# c1
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# c2
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# p1
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# p2
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
# Start  End
# 0       2
#
#
# Mapping
# [(2, 2), (3, 3)]
#
#
#
#
# c1
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# c2
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# p1
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# p2
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
# Start  End
# 3       6
#
#
# Mapping
# [(5, 5), (10, 10), (9, 9)]
#
#
#
#
# c1
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# c2
# [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 3       7
#
#
# Mapping
# [(5, 5), (10, 10), (9, 9), (7, 7)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 6       7
#
#
# Mapping
# [(7, 7)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
#
#
# nextgen_child
# [[2, 3, 8, 5, 10, 9, 7, 4, 1, 6], [2, 3, 8, 5, 10, 9, 7, 4, 1, 6], [2, 3, 8, 5, 10, 9, 7, 4, 1, 6], [2, 3, 8, 5, 10, 9, 7, 4, 1, 6], [2, 3, 8, 5, 10, 9, 7, 4, 1, 6], [2, 3, 8, 5, 10, 9, 7, 4, 1, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]]
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 8 4804
#
#
# routeCost+ 8 -> 5 6473
#
#
# routeCost+ 5 -> 10 7100
#
#
# routeCost+ 10 -> 9 7811
#
#
# routeCost+ 9 -> 7 9134
#
#
# routeCost+ 7 -> 4 9367
#
#
# routeCost+ 4 -> 1 9654
#
#
# routeCost+ 1 -> 6 11775
#
#
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 8 4804
#
#
# routeCost+ 8 -> 5 6473
#
#
# routeCost+ 5 -> 10 7100
#
#
# routeCost+ 10 -> 9 7811
#
#
# routeCost+ 9 -> 7 9134
#
#
# routeCost+ 7 -> 4 9367
#
#
# routeCost+ 4 -> 1 9654
#
#
# routeCost+ 1 -> 6 11775
#
#
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 8 4804
#
#
# routeCost+ 8 -> 5 6473
#
#
# routeCost+ 5 -> 10 7100
#
#
# routeCost+ 10 -> 9 7811
#
#
# routeCost+ 9 -> 7 9134
#
#
# routeCost+ 7 -> 4 9367
#
#
# routeCost+ 4 -> 1 9654
#
#
# routeCost+ 1 -> 6 11775
#
#
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 8 4804
#
#
# routeCost+ 8 -> 5 6473
#
#
# routeCost+ 5 -> 10 7100
#
#
# routeCost+ 10 -> 9 7811
#
#
# routeCost+ 9 -> 7 9134
#
#
# routeCost+ 7 -> 4 9367
#
#
# routeCost+ 4 -> 1 9654
#
#
# routeCost+ 1 -> 6 11775
#
#
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 8 4804
#
#
# routeCost+ 8 -> 5 6473
#
#
# routeCost+ 5 -> 10 7100
#
#
# routeCost+ 10 -> 9 7811
#
#
# routeCost+ 9 -> 7 9134
#
#
# routeCost+ 7 -> 4 9367
#
#
# routeCost+ 4 -> 1 9654
#
#
# routeCost+ 1 -> 6 11775
#
#
# routeCost+ 0 -> 2 1825
#
#
# routeCost+ 2 -> 3 2979
#
#
# routeCost+ 3 -> 8 4804
#
#
# routeCost+ 8 -> 5 6473
#
#
# routeCost+ 5 -> 10 7100
#
#
# routeCost+ 10 -> 9 7811
#
#
# routeCost+ 9 -> 7 9134
#
#
# routeCost+ 7 -> 4 9367
#
#
# routeCost+ 4 -> 1 9654
#
#
# routeCost+ 1 -> 6 11775
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# next_generation
#                              Route   Cost
# 0  [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]  11924
# 1  [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]  11924
# 2  [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]  11924
# 3  [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]  11924
# 4  [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]  11924
# 5  [2, 3, 8, 5, 10, 9, 7, 4, 1, 6]  11924
# 6  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 7  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 8  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 9  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# starting Mutation
# [8, 2]
# [1, 5, 10, 9, 7, 4, 3, 6]
# [1, 5, 10, 9, 7, 4, 3, 6, 8, 2]
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 5 4134
#
#
# routeCost+ 5 -> 10 4761
#
#
# routeCost+ 10 -> 9 5472
#
#
# routeCost+ 9 -> 7 6795
#
#
# routeCost+ 7 -> 4 7028
#
#
# routeCost+ 4 -> 3 7689
#
#
# routeCost+ 3 -> 6 9498
#
#
# routeCost+ 6 -> 8 11510
#
#
# routeCost+ 8 -> 2 12193
#
#
# Completed 2 runs of GA.
# Below are the best chromosomes:
#                              Route   Cost
# 6  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 8  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
#
#
# Total distance travelled to cover the final route of
#  Bangalore => Kolkata => Varanasi => Jaipur => Chennai => Hyderabad => Mumbai => Agra => Delhi => Udaipur => Mysore => Bangalore is 11015
# xover_pool= 3
# starting crossover
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 2       6
#
#
# Mapping
# [(1, 1), (5, 5), (10, 10), (9, 9)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 0       2
#
#
# Mapping
# [(8, 8), (2, 2)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 0       5
#
#
# Mapping
# [(8, 8), (2, 2), (1, 1), (5, 5), (10, 10)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 4       7
#
#
# Mapping
# [(10, 10), (9, 9), (7, 7)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 3       8
#
#
# Mapping
# [(5, 5), (10, 10), (9, 9), (7, 7), (4, 4)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
#
#
# nextgen_child
# [[8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]]
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# next_generation
#                              Route   Cost
# 0  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 1  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 2  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 3  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 4  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 5  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 6  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 7  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 8  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 9  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# starting Mutation
# [8, 2]
# [1, 5, 10, 9, 7, 4, 3, 6]
# [1, 5, 10, 9, 7, 4, 3, 6, 8, 2]
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 5 4134
#
#
# routeCost+ 5 -> 10 4761
#
#
# routeCost+ 10 -> 9 5472
#
#
# routeCost+ 9 -> 7 6795
#
#
# routeCost+ 7 -> 4 7028
#
#
# routeCost+ 4 -> 3 7689
#
#
# routeCost+ 3 -> 6 9498
#
#
# routeCost+ 6 -> 8 11510
#
#
# routeCost+ 8 -> 2 12193
#
#
# Completed 3 runs of GA.
# Below are the best chromosomes:
#                              Route   Cost
# 0  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 1  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
#
#
# Total distance travelled to cover the final route of
#  Bangalore => Kolkata => Varanasi => Jaipur => Chennai => Hyderabad => Mumbai => Agra => Delhi => Udaipur => Mysore => Bangalore is 11015
# xover_pool= 3
# starting crossover
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 0       5
#
#
# Mapping
# [(8, 8), (2, 2), (1, 1), (5, 5), (10, 10)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 4       5
#
#
# Mapping
# [(10, 10)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 3       5
#
#
# Mapping
# [(5, 5), (10, 10)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 0       6
#
#
# Mapping
# [(8, 8), (2, 2), (1, 1), (5, 5), (10, 10), (9, 9)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 6       8
#
#
# Mapping
# [(7, 7), (4, 4)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
#
#
# nextgen_child
# [[8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]]
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# next_generation
#                              Route   Cost
# 0  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 1  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 2  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 3  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 4  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 5  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 6  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 7  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 8  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 9  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# starting Mutation
# [8, 2]
# [1, 5, 10, 9, 7, 4, 3, 6]
# [1, 5, 10, 9, 7, 4, 3, 6, 8, 2]
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 5 4134
#
#
# routeCost+ 5 -> 10 4761
#
#
# routeCost+ 10 -> 9 5472
#
#
# routeCost+ 9 -> 7 6795
#
#
# routeCost+ 7 -> 4 7028
#
#
# routeCost+ 4 -> 3 7689
#
#
# routeCost+ 3 -> 6 9498
#
#
# routeCost+ 6 -> 8 11510
#
#
# routeCost+ 8 -> 2 12193
#
#
# [8, 2]
# [1, 5, 10, 9, 7, 4, 3, 6]
# [1, 5, 10, 9, 7, 4, 3, 6, 8, 2]
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 5 4134
#
#
# routeCost+ 5 -> 10 4761
#
#
# routeCost+ 10 -> 9 5472
#
#
# routeCost+ 9 -> 7 6795
#
#
# routeCost+ 7 -> 4 7028
#
#
# routeCost+ 4 -> 3 7689
#
#
# routeCost+ 3 -> 6 9498
#
#
# routeCost+ 6 -> 8 11510
#
#
# routeCost+ 8 -> 2 12193
#
#
# Completed 4 runs of GA.
# Below are the best chromosomes:
#                              Route   Cost
# 0  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 1  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
#
#
# Total distance travelled to cover the final route of
#  Bangalore => Kolkata => Varanasi => Jaipur => Chennai => Hyderabad => Mumbai => Agra => Delhi => Udaipur => Mysore => Bangalore is 11015
# xover_pool= 3
# starting crossover
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 3       4
#
#
# Mapping
# [(5, 5)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 5       8
#
#
# Mapping
# [(9, 9), (7, 7), (4, 4)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 1       8
#
#
# Mapping
# [(2, 2), (1, 1), (5, 5), (10, 10), (9, 9), (7, 7), (4, 4)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 2       5
#
#
# Mapping
# [(1, 1), (5, 5), (10, 10)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 0       6
#
#
# Mapping
# [(8, 8), (2, 2), (1, 1), (5, 5), (10, 10), (9, 9)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
#
#
# nextgen_child
# [[8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]]
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# next_generation
#                              Route   Cost
# 0  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 1  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 2  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 3  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 4  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 5  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 6  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 7  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 8  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 9  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# starting Mutation
# [8, 2]
# [1, 5, 10, 9, 7, 4, 3, 6]
# [1, 5, 10, 9, 7, 4, 3, 6, 8, 2]
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 5 4134
#
#
# routeCost+ 5 -> 10 4761
#
#
# routeCost+ 10 -> 9 5472
#
#
# routeCost+ 9 -> 7 6795
#
#
# routeCost+ 7 -> 4 7028
#
#
# routeCost+ 4 -> 3 7689
#
#
# routeCost+ 3 -> 6 9498
#
#
# routeCost+ 6 -> 8 11510
#
#
# routeCost+ 8 -> 2 12193
#
#
# Completed 5 runs of GA.
# Below are the best chromosomes:
#                              Route   Cost
# 0  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 1  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
#
#
# Total distance travelled to cover the final route of
#  Bangalore => Kolkata => Varanasi => Jaipur => Chennai => Hyderabad => Mumbai => Agra => Delhi => Udaipur => Mysore => Bangalore is 11015
# xover_pool= 3
# starting crossover
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 3       4
#
#
# Mapping
# [(5, 5)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 2       5
#
#
# Mapping
# [(1, 1), (5, 5), (10, 10)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 4       8
#
#
# Mapping
# [(10, 10), (9, 9), (7, 7), (4, 4)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 5       7
#
#
# Mapping
# [(9, 9), (7, 7)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# p2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
# Start  End
# 6       8
#
#
# Mapping
# [(7, 7), (4, 4)]
#
#
#
#
# c1
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
# c2
# [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]
#
#
#
#
# nextgen_child
# [[8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6], [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]]
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
#
#
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# routeCost+ 0 -> 8 1862
#
#
# routeCost+ 8 -> 2 2545
#
#
# routeCost+ 2 -> 1 3394
# routeCost+ 1 -> 5 5502
#
#
# routeCost+ 5 -> 10 6129
#
#
# routeCost+ 10 -> 9 6840
#
#
# routeCost+ 9 -> 7 8163
#
#
# routeCost+ 7 -> 4 8396
#
#
# routeCost+ 4 -> 3 9057
#
#
# routeCost+ 3 -> 6 10866
#
#
# next_generation
#                              Route   Cost
# 0  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 1  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 2  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 3  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 4  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 5  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 6  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 7  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 8  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 9  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# starting Mutation
# [8, 2]
# [1, 5, 10, 9, 7, 4, 3, 6]
# [1, 5, 10, 9, 7, 4, 3, 6, 8, 2]
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 5 4134
#
#
# routeCost+ 5 -> 10 4761
#
#
# routeCost+ 10 -> 9 5472
#
#
# routeCost+ 9 -> 7 6795
#
#
# routeCost+ 7 -> 4 7028
#
#
# routeCost+ 4 -> 3 7689
#
#
# routeCost+ 3 -> 6 9498
#
#
# routeCost+ 6 -> 8 11510
#
#
# routeCost+ 8 -> 2 12193
#
#
# [8, 2]
# [1, 5, 10, 9, 7, 4, 3, 6]
# [1, 5, 10, 9, 7, 4, 3, 6, 8, 2]
# routeCost+ 0 -> 1 2026
#
#
# routeCost+ 1 -> 5 4134
#
#
# routeCost+ 5 -> 10 4761
#
#
# routeCost+ 10 -> 9 5472
#
#
# routeCost+ 9 -> 7 6795
#
#
# routeCost+ 7 -> 4 7028
#
#
# routeCost+ 4 -> 3 7689
#
#
# routeCost+ 3 -> 6 9498
#
#
# routeCost+ 6 -> 8 11510
#
#
# routeCost+ 8 -> 2 12193
#
#
# Completed 6 runs of GA.
# Below are the best chromosomes:
#                              Route   Cost
# 0  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
# 2  [8, 2, 1, 5, 10, 9, 7, 4, 3, 6]  11015
#
#
# Total distance travelled to cover the final route of
#  Bangalore => Kolkata => Varanasi => Jaipur => Chennai => Hyderabad => Mumbai => Agra => Delhi => Udaipur => Mysore => Bangalore is 11015

# %%
print(best_solution)
print(best_cost)
# Out:
# [8, 3, 7, 4, 1, 5, 6, 9, 2, 10]
# 11825

# %%
final_route = []
for i in best_solution:
    final_route.append(cities_mapping[i])
    
final_route = [starting_point] + final_route + [starting_point]

print("Total distance travelled to cover the final route of \n {} is {}".format(" => ".join(final_route),best_cost))
# Out:
# Total distance travelled to cover the final route of
#  Bangalore => Kolkata => Udaipur => Agra => Delhi => Jaipur => Chennai => Mysore => Mumbai => Varanasi => Hyderabad => Bangalore is 11825
