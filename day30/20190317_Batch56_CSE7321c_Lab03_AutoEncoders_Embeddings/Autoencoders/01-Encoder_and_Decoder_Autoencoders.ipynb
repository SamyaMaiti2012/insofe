# %% [markdown]
# ## Encoder and Decoder using Autoencoder

# %%
import os
PATH = os.getcwd()

# %%
os.chdir(PATH)

# %%
from IPython.display import Image
Image(filename='encodeco.png')

# %% [markdown]
# Data Set: MNIST
#
#     Note: Discard the labels

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Normalize all values between 0 and 1

# %%
x_train = x_train.astype('float32')/255.
x_test = x_test.astype('float32')/255.

# %%
print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
x_train.shape[1:]
# Out:
# (28, 28)

# %% [markdown]
# Flatten the 28x28 images into vectors of size 784.

# %%
x_train = x_train.reshape(x_train.shape[0], np.prod(x_train.shape[1:]))
x_test = x_test.reshape(x_test.shape[0], np.prod(x_test.shape[1:]))

print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# #### Fully-connected neural layer as encoder and as decoder:

# %%
from keras.layers import Input, Dense
from keras.models import Model

# %%
# The size of encoded and actual representations
encoding_dim = 32 
actual_dim = x_train.shape[1] #784

# %%
# Input placeholder
input_img = Input(shape=(actual_dim,))

# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)

# "decoded" is the lossy reconstruction of the input
decoded = Dense(actual_dim, activation='sigmoid')(encoded)

# %%
# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)

# %%
print(autoencoder.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               25872
# =================================================================
# Total params: 50,992
# Trainable params: 50,992
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Create a separate encoder model:

# %%
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# %%
print(encoder.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                25120
# =================================================================
# Total params: 25,120
# Trainable params: 25,120
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Create a separate decoder model

# %%
# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))

# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1](encoded_input)

# create the decoder model
decoder = Model(encoded_input, decoder_layer)

# %%
print(decoder.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               25872
# =================================================================
# Total params: 25,872
# Trainable params: 25,872
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Configure the model to use a per-pixel binary crossentropy loss, and the Adadelta optimizer:

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %% [markdown]
# Train our autoencoder for 50 epochs:

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.3557 - val_loss: 0.2710
# Epoch 2/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2636 - val_loss: 0.2525
# Epoch 3/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2421 - val_loss: 0.2301
# Epoch 4/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2224 - val_loss: 0.2128
# Epoch 5/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2075 - val_loss: 0.2001
# Epoch 6/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1962 - val_loss: 0.1900
# Epoch 7/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1874 - val_loss: 0.1822
# Epoch 8/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1803 - val_loss: 0.1759
# Epoch 9/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1744 - val_loss: 0.1706
# Epoch 10/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1694 - val_loss: 0.1659
# Epoch 11/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1650 - val_loss: 0.1616
# Epoch 12/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1610 - val_loss: 0.1577
# Epoch 13/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1572 - val_loss: 0.1541
# Epoch 14/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1537 - val_loss: 0.1507
# Epoch 15/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1505 - val_loss: 0.1475
# Epoch 16/50
# 60000/60000 [==============================] - 1s 25us/step - loss: 0.1475 - val_loss: 0.1447
# Epoch 17/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1447 - val_loss: 0.1419
# Epoch 18/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1421 - val_loss: 0.1395
# Epoch 19/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1396 - val_loss: 0.1372
# Epoch 20/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1374 - val_loss: 0.1349
# Epoch 21/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1353 - val_loss: 0.1330
# Epoch 22/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1333 - val_loss: 0.1309
# Epoch 23/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1314 - val_loss: 0.1292
# Epoch 24/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1297 - val_loss: 0.1273
# Epoch 25/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1280 - val_loss: 0.1257
# Epoch 26/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1264 - val_loss: 0.1243
# Epoch 27/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1249 - val_loss: 0.1226
# Epoch 28/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1235 - val_loss: 0.1212
# Epoch 29/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1221 - val_loss: 0.1199
# Epoch 30/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1208 - val_loss: 0.1186
# Epoch 31/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1195 - val_loss: 0.1174
# Epoch 32/50
# 60000/60000 [==============================] - 1s 25us/step - loss: 0.1184 - val_loss: 0.1162
# Epoch 33/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1172 - val_loss: 0.1151
# Epoch 34/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1162 - val_loss: 0.1140
# Epoch 35/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1152 - val_loss: 0.1131
# Epoch 36/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1142 - val_loss: 0.1121
# Epoch 37/50
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.1133 - val_loss: 0.1112
# Epoch 38/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1125 - val_loss: 0.1104
# Epoch 39/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1117 - val_loss: 0.1096
# Epoch 40/50
# 60000/60000 [==============================] - 1s 25us/step - loss: 0.1109 - val_loss: 0.1089
# Epoch 41/50
# 60000/60000 [==============================] - 2s 25us/step - loss: 0.1102 - val_loss: 0.1082
# Epoch 42/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1095 - val_loss: 0.1075
# Epoch 43/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1089 - val_loss: 0.1069
# Epoch 44/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1083 - val_loss: 0.1063
# Epoch 45/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1078 - val_loss: 0.1058
# Epoch 46/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1072 - val_loss: 0.1053
# Epoch 47/50
# 60000/60000 [==============================] - 1s 25us/step - loss: 0.1067 - val_loss: 0.1048
# Epoch 48/50
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1063 - val_loss: 0.1044
# Epoch 49/50
# 60000/60000 [==============================] - 1s 25us/step - loss: 0.1059 - val_loss: 0.1040
# Epoch 50/50
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.1055 - val_loss: 0.1036

# %% [markdown]
# Visualize the reconstructed inputs and the encoded representations using Matplotlib.

# %%
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)

decoded_imgs = decoder.predict(encoded_imgs)

# %%
# use Matplotlib 
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# Ref:
#
#     https://blog.keras.io/building-autoencoders-in-keras.html
