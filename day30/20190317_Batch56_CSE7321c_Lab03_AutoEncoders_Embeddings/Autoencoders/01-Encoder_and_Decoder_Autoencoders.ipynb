# %% [markdown]
# ## Encoder and Decoder using Autoencoder

# %%
import os
PATH = os.getcwd()

# %%
os.chdir(PATH)

# %%
from IPython.display import Image
Image(filename='encodeco.png')

# %% [markdown]
# Data Set: MNIST
#
#     Note: Discard the labels

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 8s 1us/step

# %% [markdown]
# Normalize all values between 0 and 1

# %%
x_train = x_train.astype('float32')/255.
x_test = x_test.astype('float32')/255.

# %%
print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# Flatten the 28x28 images into vectors of size 784.

# %%
x_train = x_train.reshape(x_train.shape[0], np.prod(x_train.shape[1:]))
x_test = x_test.reshape(x_test.shape[0], np.prod(x_test.shape[1:]))

print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# #### Fully-connected neural layer as encoder and as decoder:

# %%
from keras.layers import Input, Dense
from keras.models import Model

# %%
# The size of encoded and actual representations
encoding_dim = 32 
actual_dim = x_train.shape[1] #784

# %%
# Input placeholder
input_img = Input(shape=(actual_dim,))

# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)

# "decoded" is the lossy reconstruction of the input
decoded = Dense(actual_dim, activation='sigmoid')(encoded)

# %%
# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)

# %%
print(autoencoder.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               25872
# =================================================================
# Total params: 50,992
# Trainable params: 50,992
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Create a separate encoder model:

# %%
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# %%
print(encoder.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                25120
# =================================================================
# Total params: 25,120
# Trainable params: 25,120
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Create a separate decoder model

# %%
# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))

# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1](encoded_input)

# create the decoder model
decoder = Model(encoded_input, decoder_layer)

# %%
print(decoder.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               25872
# =================================================================
# Total params: 25,872
# Trainable params: 25,872
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Configure the model to use a per-pixel binary crossentropy loss, and the Adadelta optimizer:

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %% [markdown]
# Train our autoencoder for 50 epochs:

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.3561 - val_loss: 0.2703
# Epoch 2/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.2627 - val_loss: 0.2515
# Epoch 3/50
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.2407 - val_loss: 0.2281
# Epoch 4/50
# 60000/60000 [==============================] - 4s 58us/step - loss: 0.2201 - val_loss: 0.2101
# Epoch 5/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.2050 - val_loss: 0.1977
# Epoch 6/50
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.1943 - val_loss: 0.1886
# Epoch 7/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1864 - val_loss: 0.1816
# Epoch 8/50
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.1799 - val_loss: 0.1756
# Epoch 9/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.1743 - val_loss: 0.1703
# Epoch 10/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.1693 - val_loss: 0.1656
# Epoch 11/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1648 - val_loss: 0.1612
# Epoch 12/50
# 60000/60000 [==============================] - 3s 58us/step - loss: 0.1606 - val_loss: 0.1572
# Epoch 13/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1568 - val_loss: 0.1535
# Epoch 14/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.1532 - val_loss: 0.1502
# Epoch 15/50
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.1500 - val_loss: 0.1470
# Epoch 16/50
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.1470 - val_loss: 0.1440
# Epoch 17/50
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.1441 - val_loss: 0.1412
# Epoch 18/50
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.1414 - val_loss: 0.1385
# Epoch 19/50
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.1388 - val_loss: 0.1360
# Epoch 20/50
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.1364 - val_loss: 0.1337
# Epoch 21/50
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.1341 - val_loss: 0.1313
# Epoch 22/50
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.1318 - val_loss: 0.1291
# Epoch 23/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1297 - val_loss: 0.1271
# Epoch 24/50
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.1277 - val_loss: 0.1251
# Epoch 25/50
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.1258 - val_loss: 0.1233
# Epoch 26/50
# 60000/60000 [==============================] - 3s 58us/step - loss: 0.1240 - val_loss: 0.1215
# Epoch 27/50
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.1222 - val_loss: 0.1198
# Epoch 28/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.1206 - val_loss: 0.1182
# Epoch 29/50
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.1191 - val_loss: 0.1167
# Epoch 30/50
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.1177 - val_loss: 0.1154
# Epoch 31/50
# 60000/60000 [==============================] - ETA: 0s - loss: 0.116 - 4s 62us/step - loss: 0.1164 - val_loss: 0.1141
# Epoch 32/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1152 - val_loss: 0.1129
# Epoch 33/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1140 - val_loss: 0.1119
# Epoch 34/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1130 - val_loss: 0.1109
# Epoch 35/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1120 - val_loss: 0.1099
# Epoch 36/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1111 - val_loss: 0.1091
# Epoch 37/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1103 - val_loss: 0.1082
# Epoch 38/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1095 - val_loss: 0.1075
# Epoch 39/50
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.1088 - val_loss: 0.1068
# Epoch 40/50
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.1081 - val_loss: 0.1062
# Epoch 41/50
# 60000/60000 [==============================] - 3s 58us/step - loss: 0.1075 - val_loss: 0.1056
# Epoch 42/50
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.1069 - val_loss: 0.1051
# Epoch 43/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1064 - val_loss: 0.1045
# Epoch 44/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1059 - val_loss: 0.1041
# Epoch 45/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1054 - val_loss: 0.1036
# Epoch 46/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1049 - val_loss: 0.1032
# Epoch 47/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1045 - val_loss: 0.1028
# Epoch 48/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.1041 - val_loss: 0.1024
# Epoch 49/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1037 - val_loss: 0.1020
# Epoch 50/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.1034 - val_loss: 0.1017

# %% [markdown]
# Visualize the reconstructed inputs and the encoded representations using Matplotlib.

# %%
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)

decoded_imgs = decoder.predict(encoded_imgs)

# %%
# use Matplotlib 
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# Ref:
#
#     https://blog.keras.io/building-autoencoders-in-keras.html
