# %%
# Loading Packages
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from sklearn.datasets import fetch_20newsgroups
import pandas as pd

# %%
from IPython.display import Image
Image("img/SingularValueDecomposition.jpg")

# %%
# Displaying the different topics of train data
topics = fetch_20newsgroups(subset="train")
topics.target_names
# Out:
# Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
print(topics.data[0])
print("Next Newsgroup... \n\n")
print(topics.data[1])
# Out:
# From: lerxst@wam.umd.edu (where's my thing)
# Subject: WHAT car is this!?
# Nntp-Posting-Host: rac3.wam.umd.edu
# Organization: University of Maryland, College Park
# Lines: 15
#
#  I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.
#
# Thanks,
# - IL
#    ---- brought to you by your neighborhood Lerxst ----
#
#
#
#
#
# Next Newsgroup...
#
#
# From: guykuo@carson.u.washington.edu (Guy Kuo)
# Subject: SI Clock Poll - Final Call
# Summary: Final call for SI clock reports
# Keywords: SI,acceleration,clock,upgrade
# Article-I.D.: shelley.1qvfo9INNc3s
# Organization: University of Washington
# Lines: 11
# NNTP-Posting-Host: carson.u.washington.edu
#
# A fair number of brave souls who upgraded their SI clock oscillator have
# shared their experiences for this poll. Please send a brief message detailing
# your experiences with the procedure. Top speed attained, CPU rated speed,
# add on cards and adapters, heat sinks, hour of usage per day, floppy disk
# functionality with 800 and 1.4 m floppies are especially requested.
#
# I will be summarizing in the next two days, so please add to the network
# knowledge base if you have done the clock upgrade and haven't answered this
# poll. Thanks.
#
# Guy Kuo <guykuo@u.washington.edu>

# %%
# Importing both train and test data
X_train =  pd.DataFrame(
    fetch_20newsgroups(random_state=1,subset="train",remove=('headers', 'footers', 'quotes')).data)

X_test = pd.DataFrame(
    fetch_20newsgroups(random_state=1,subset="test",remove=('headers', 'footers', 'quotes')).data)

# %%
X_train.shape
# Out:
# (11314, 1)

# %%
X_test.shape
# Out:
# (7532, 1)

# %%
# Displaying the first 5 rows
X_train.head(5)
# Out:
#                                                    0
# 0  Well i'm not sure about the story nad it did s...
# 1  \n\n\n\n\n\n\nYeah, do you expect people to re...
# 2  Although I realize that principle is not one o...
# 3  Notwithstanding all the legitimate fuss about ...
# 4  Well, I will have to change the scoring on my ...

# %%
X_train[0][0]
# Out:
# "Well i'm not sure about the story nad it did seem biased. What\nI disagree with is your statement that the U.S. Media is out to\nruin Israels reputation. That is rediculous. The U.S. media is\nthe most pro-israeli media in the world. Having lived in Europe\nI realize that incidences such as the one described in the\nletter have occured. The U.S. media as a whole seem to try to\nignore them. The U.S. is subsidizing Israels existance and the\nEuropeans are not (at least not to the same degree). So I think\nthat might be a reason they report more clearly on the\natrocities.\n\tWhat is a shame is that in Austria, daily reports of\nthe inhuman acts commited by Israeli soldiers and the blessing\nreceived from the Government makes some of the Holocaust guilt\ngo away. After all, look how the Jews are treating other races\nwhen they got power. It is unfortunate.\n"

# %%
X_test.head()
# Out:
#                                                    0
# 0  : In article <34592@oasys.dt.navy.mil> odell@o...
# 1  Ithaca technical support can be reached at:\n\...
# 2  Devorski unfortunately helped to taint an othe...
# 3  \nI would further add that a 486/50,S3/928,8mb...
# 4  A rep at the dealer (actually it's a universit...

# %%
# Tf-idf
vectorizer = TfidfVectorizer(max_df = 0.7,stop_words='english')

# %%
# SVD
from sklearn.decomposition import TruncatedSVD
svd_model = TruncatedSVD(n_components=500, 
                          random_state=42)

# %%
X_train[0][0]
# Out:
# "Well i'm not sure about the story nad it did seem biased. What\nI disagree with is your statement that the U.S. Media is out to\nruin Israels reputation. That is rediculous. The U.S. media is\nthe most pro-israeli media in the world. Having lived in Europe\nI realize that incidences such as the one described in the\nletter have occured. The U.S. media as a whole seem to try to\nignore them. The U.S. is subsidizing Israels existance and the\nEuropeans are not (at least not to the same degree). So I think\nthat might be a reason they report more clearly on the\natrocities.\n\tWhat is a shame is that in Austria, daily reports of\nthe inhuman acts commited by Israeli soldiers and the blessing\nreceived from the Government makes some of the Holocaust guilt\ngo away. After all, look how the Jews are treating other races\nwhen they got power. It is unfortunate.\n"

# %%
# Building the pipeline
from sklearn.pipeline import Pipeline
svd_transformer = Pipeline([('tfidf', vectorizer), 
                            ('svd', svd_model)])
preprocessing_model = svd_transformer.fit(X_train[0])
svd_matrix_train = preprocessing_model.transform(X_train[0])

# %%
svd_matrix_train.shape
# Out:
# (11314, 500)

# %%
svd_matrix_train
# Out:
# array([[ 0.08690072, -0.05274129, -0.01616815, ...,  0.00982699,
#          0.03411385,  0.01496907],
#        [ 0.12571505, -0.03759298,  0.01870855, ...,  0.01486599,
#          0.01532102, -0.00847011],
#        [ 0.11543529, -0.05215308, -0.02240145, ...,  0.02234933,
#         -0.01390385, -0.0074297 ],
#        ...,
#        [ 0.06512122, -0.01967664, -0.02061429, ..., -0.010884  ,
#         -0.00857213, -0.00100804],
#        [ 0.03353651,  0.02204399, -0.00068135, ..., -0.0118142 ,
#         -0.01324368,  0.00595057],
#        [ 0.17359084, -0.03098295, -0.04834866, ...,  0.02708178,
#          0.00909409, -0.02168712]])

# %%
vectorizer.vocabulary_
# Out:
# {'sure': 86350,
#  'story': 85365,
#  'nad': 64707,
#  'did': 33485,
#  'biased': 22639,
#  'disagree': 33782,
#  'statement': 84947,
#  'media': 60543,
#  'ruin': 79344,
#  'israels': 51134,
#  'reputation': 77452,
#  'rediculous': 76603,
#  'pro': 73080,
#  'israeli': 51126,
#  'world': 96983,
#  'having': 45783,
#  'lived': 56869,
#  'europe': 38092,
#  'realize': 76261,
#  'incidences': 49393,
#  'described': 32982,
#  'letter': 56182,
#  'occured': 67346,
#  'try': 90153,
#  'ignore': 48697,
#  'subsidizing': 85826,
#  'existance': 38536,
#  'europeans': 38094,
#  'degree': 32529,
#  'think': 88487,
#  'reason': 76307,
#  'report': 77367,
#  'clearly': 27763,
#  'atrocities': 20206,
#  'shame': 81809,
#  'austria': 20446,
#  'daily': 31623,
#  'reports': 77376,
#  'inhuman': 49918,
#  'acts': 16707,
#  'commited': 28551,
#  'soldiers': 83598,
#  'blessing': 23136,
#  'received': 76389,
#  'government': 43957,
#  'makes': 59163,
#  'holocaust': 46998,
#  'guilt': 44670,
#  'away': 20732,
#  'look': 57244,
#  'jews': 52045,
#  'treating': 89864,
#  'races': 75591,
#  'got': 43914,
#  'power': 72393,
#  'unfortunate': 91786,
#  'yeah': 99604,
#  'expect': 38600,
#  'people': 70436,
#  'read': 76207,
#  'faq': 39428,
#  'actually': 16715,
#  'accept': 16404,
#  'hard': 45557,
#  'atheism': 20133,
#  'need': 65165,
#  'little': 56849,
#  'leap': 55885,
#  'faith': 39317,
#  'jimmy': 52150,
#  'logic': 57176,
#  'runs': 79398,
#  'steam': 85032,
#  'jim': 52144,
#  'sorry': 83758,
#  'pity': 71397,
#  'feelings': 39790,
#  'denial': 32770,
#  'oh': 67604,
#  'just': 52861,
#  'pretend': 72894,
#  'end': 37118,
#  'happily': 45531,
#  'maybe': 59935,
#  'start': 84914,
#  'new': 65475,
#  'newsgroup': 65530,
#  'alt': 18083,
#  'atheist': 20134,
#  'won': 96869,
#  'bummin': 24579,
#  'bye': 24895,
#  'big': 22694,
#  'don': 34696,
#  'forget': 41117,
#  'flintstone': 40679,
#  'chewables': 26917,
#  'bake': 21411,
#  'timmons': 88876,
#  'iii': 48774,
#  'principle': 73008,
#  'strongest': 85568,
#  'points': 71962,
#  'like': 56591,
#  'know': 54493,
#  'ask': 19822,
#  'question': 75083,
#  'sort': 83759,
#  'arab': 19310,
#  'countries': 30061,
#  'want': 95488,
#  'continue': 29511,
#  'tank': 87474,
#  'charade': 26707,
#  'fixation': 40443,
#  'israel': 51125,
#  'stop': 85330,
#  'asking': 19831,
#  'questions': 75095,
#  'work': 96948,
#  'treatment': 89867,
#  'decades': 32159,
#  'bad': 21323,
#  'begin': 22126,
#  'attack': 20227,
#  'group': 44440,
#  'recognizes': 76464,
#  'stupid': 85652,
#  'center': 26360,
#  'policy': 72011,
#  'research': 77504,
#  'fancy': 39404,
#  'bigot': 22710,
#  'hates': 45737,
#  'notwithstanding': 66390,
#  'legitimate': 56023,
#  'fuss': 41934,
#  'proposal': 73424,
#  'change': 26651,
#  'att': 20215,
#  'product': 73172,
#  'area': 19415,
#  'priced': 72953,
#  '1000': 1471,
#  'suspect': 86446,
#  'clipper': 27867,
#  'phones': 70995,
#  'came': 25492,
#  'customer': 31039,
#  'key': 53808,
#  'automatically': 20524,
#  'preregistered': 72791,
#  'authorities': 20474,
#  'aside': 19815,
#  'attempting': 20249,
#  'legitimize': 56026,
#  'solidify': 83622,
#  'fed': 39757,
#  'posture': 72336,
#  'direction': 33739,
#  'yes': 99654,
#  'technology': 87784,
#  'eventually': 38190,
#  'drive': 35078,
#  'cost': 29982,
#  'promote': 73321,
#  'widespread': 96313,
#  'use': 92600,
#  'present': 72814,
#  'man': 59263,
#  'street': 85469,
#  'going': 43777,
#  'purchase': 73967,
#  'crypto': 30680,
#  'telephone': 87882,
#  'especially': 37867,
#  'guy': 44793,
#  'probably': 73091,
#  'doesn': 34619,
#  'missing': 61941,
#  'real': 76241,
#  'gov': 43941,
#  'year': 99605,
#  'air': 17534,
#  'tight': 88791,
#  'voice': 94465,
#  'privacy': 73043,
#  'phone': 70985,
#  'line': 56676,
#  'close': 27905,
#  'nearest': 65108,
#  'pc': 70140,
#  'problematic': 73105,
#  'scenario': 80581,
#  'extent': 38775,
#  'usage': 92588,
#  'surpasses': 86387,
#  'underground': 91600,
#  'stature': 84989,
#  'pgp': 70841,
#  'scoring': 80804,
#  'playoff': 71634,
#  'pool': 72131,
#  'unfortunately': 91787,
#  'time': 88835,
#  'right': 78195,
#  'certainly': 26431,
#  'post': 72291,
#  'rules': 79357,
#  'tomorrow': 89206,
#  'does': 34617,
#  'matter': 59822,
#  'll': 56988,
#  'enter': 37320,
#  'good': 43852,
#  'keith': 53688,
#  'keller': 53698,
#  'let': 56169,
#  'rangers': 75822,
#  'quakers': 74976,
#  'kkeller': 54346,
#  'mail': 59071,
#  'sas': 80303,
#  'upenn': 92383,
#  'edu': 36234,
#  'ivy': 51330,
#  'league': 55864,
#  'champs': 26632,
#  'morton': 63021,
#  'smith': 83270,
#  '_jesus': 15198,
#  'magician_': 58985,
#  'old': 67759,
#  'lazarus': 55741,
#  'wasn': 95587,
#  'dead': 32072,
#  'tomb': 89194,
#  'initiation': 49953,
#  'rite': 78315,
#  'magi': 58977,
#  'cult': 30909,
#  'jesus': 52019,
#  'appears': 19074,
#  'day': 31927,
#  'stay': 85001,
#  'normal': 66277,
#  'wonder': 96870,
#  'ok': 67681,
#  'record': 76519,
#  'shows': 82222,
#  'iisi': 48792,
#  '64kb': 10072,
#  'cache': 25302,
#  'small': 83208,
#  'attach': 20219,
#  'measured': 60475,
#  'programs': 73244,
#  '64': 10019,
#  'kb': 53565,
#  'speedup': 84105,
#  'varies': 93418,
#  'lot': 57335,
#  'app': 19045,
#  'ranging': 75824,
#  '40': 7454,
#  'average': 20614,
#  '20': 4306,
#  '25': 4899,
#  'subjective': 85740,
#  'difference': 33538,
#  'great': 44241,
#  'noticable': 66362,
#  'simple': 82570,
#  'card': 25754,
#  'transform': 89692,
#  'enormously': 37276,
#  'better': 22475,
#  'fpu': 41313,
#  'conventional': 29622,
#  'wisdom': 96592,
#  'says': 80437,
#  'cards': 25769,
#  'makers': 59162,
#  'offer': 67520,
#  '32k': 6282,
#  '64k': 10070,
#  'caches': 25305,
#  'bought': 23738,
#  'wave': 95651,
#  '150': 2778,
#  'absolutely': 16290,
#  'problems': 73108,
#  'complete': 28755,
#  'speedometer': 84100,
#  'check': 26805,
#  'called': 25437,
#  'performance': 70498,
#  'rating': 75913,
#  'numbers': 66687,
#  'cheers': 26834,
#  'file': 40217,
#  'converted': 29640,
#  'binhex': 22813,
#  '0kbfkp': 1076,
#  'q0': 74205,
#  '338083e': 6346,
#  'qk3': 74639,
#  'bgj': 22541,
#  'cfgigfh': 26487,
#  'ghq': 43244,
#  'qsqbuc': 74902,
#  'squu': 84524,
#  'qscfphghl': 74875,
#  'hcl': 45866,
#  'kjqtu': 54264,
#  'ldh': 55833,
#  'hbl': 45840,
#  'ucucj': 91007,
#  'gq9hgik': 44010,
#  'hcakr9spij': 45859,
#  'qrq': 74826,
#  'quj': 75164,
#  'ucld': 90977,
#  'quutqc': 75192,
#  'dl3j': 34424,
#  '3lt': 7187,
#  'uu': 92786,
#  'quubut': 75190,
#  'l3': 55120,
#  'qjs': 74633,
#  'ut': 92701,
#  'ud': 91013,
#  'tuuqcq3': 90418,
#  'ucfj': 90956,
#  'c4acsl': 25068,
#  'b8': 21097,
#  '9l0a': 14240,
#  '21z': 4564,
#  '1i': 3826,
#  'cqfm': 30245,
#  'vxmhha': 94877,
#  'irdjpcvr': 50895,
#  'lucvsz2si8j': 57637,
#  'jpi': 52567,
#  'lzq0a': 57920,
#  'al8xrhjf': 17738,
#  'lj09': 56896,
#  'az2tv6l': 20864,
#  '9ln': 14258,
#  'eap': 35892,
#  'rei8': 76893,
#  'vipiqkfdk': 94167,
#  'zv': 101217,
#  't5lkc0xz6lghf': 87096,
#  'ik': 48831,
#  'lkh': 56968,
#  'q6': 74330,
#  'qhh2milc': 74581,
#  'q2iq': 74253,
#  'gesp': 43103,
#  'ejn': 36520,
#  'bhmdhll': 22613,
#  'qh': 74573,
#  'lr': 57501,
#  'e26c2': 35697,
#  'qbqsrmm': 74474,
#  'pa': 69352,
#  'jpgxqcpr2ryr9eyd0': 52565,
#  'mh0': 61259,
#  'h1rj1': 44976,
#  'ha': 45155,
#  'pclhrsg6pf2eiymc4ris60efp': 70167,
#  'cge': 26532,
#  'vr': 94648,
#  'trafa': 89578,
#  'qka': 74643,
#  'pg8jks': 70826,
#  'fe1mcbikfqc': 39718,
#  '9k': 14223,
#  '0rr': 1248,
#  'bddt': 21925,
#  'xp3z': 98493,
#  'v04l8d82feu01v4k': 92975,
#  '9u': 14416,
#  'jad': 51696,
#  'fza': 42108,
#  'ezr3': 38923,
#  'egtyknxh49sjf2ei': 36402,
#  '5el3': 9272,
#  'vz': 94907,
#  'vf': 93912,
#  'btbhjlex3pe0kj8': 24381,
#  'zkh': 100790,
#  '9cc3': 14033,
#  'fj': 40458,
#  'khgzc': 53986,
#  'bhhnv9': 22579,
#  'dc6xd': 31996,
#  's58dfd': 79786,
#  'pj': 71425,
#  'ei': 36424,
#  'cxhkel': 31166,
#  'pyyy': 74186,
#  '1f0rg': 3747,
#  'jm0rjtcymi4b1kbb': 52285,
#  'pubq': 73820,
#  'pu9': 73795,
#  'm1mihg': 58047,
#  'yr': 99972,
#  'eung1': 38074,
#  'msap': 63554,
#  'mr': 63393,
#  'dinq': 33690,
#  'mqjza': 63340,
#  '4bq': 8094,
#  'mimq': 61678,
#  'kc9': 53607,
#  'mc': 60069,
#  'f88e9u': 39105,
#  'y4u5exb': 99305,
#  '6t8d': 10940,
#  'r3ae': 75382,
#  '10padk': 1890,
#  'cak': 25359,
#  'ea6sthlia9hf': 35862,
#  'da': 31560,
#  '2ba2': 5349,
#  '2vir': 5952,
#  'ti': 88721,
#  '6v': 11007,
#  'ej': 36502,
#  'gs': 44505,
#  'qqd': 74782,
#  '2p': 5719,
#  'm49m9idhhm2fruq2ek': 58263,
#  'g3e': 42192,
#  'vi': 93976,
#  'rqj': 79150,
#  '0jf': 1063,
#  'yi2ql': 99732,
#  '0qhh': 1216,
#  '339': 6350,
#  '9hy46': 14186,
#  'tr': 89519,
#  'zkxi': 100802,
#  'pqrqkcu3': 72497,
#  'ed9r': 36163,
#  'cr': 30254,
#  'qciuk': 74488,
#  'zmef': 100841,
#  'iyi': 51371,
#  'bqmeffkt5bb': 23867,
#  'jhyl2k': 52114,
#  '0pxve0b': 1206,
#  'uam121d': 90898,
#  'cc': 26162,
#  'xl': 98284,
#  'iejf8s': 48616,
#  'a6': 15917,
#  'p8p0zc': 69300,
#  '6h0ajcy1br': 10664,
#  'jdm3': 51902,
#  'lj1': 56897,
#  '5bi': 9190,
#  'sc2jh': 80479,
#  'qetfvk961rr': 74534,
#  'zviq': 101226,
#  'rb': 76004,
#  'th3': 88259,
#  'b3f0r': 20996,
#  'cp': 30170,
#  'uy1': 92941,
#  'ju53jy': 52714,
#  '5p': 9536,
#  'rcdpaxafrl': 76058,
#  'xrhf': 98585,
#  'dmv1i': 34504,
#  'dm': 34457,
#  'f4nmlp5jd': 39033,
#  'xn0': 98436,
#  'k5c91': 53158,
#  '4qb9c5ke1h': 8388,
#  'kiara': 54031,
#  'nta': 66608,
#  'b9': 21139,
#  'yyl5tm5': 100165,
#  'f2': 38973,
#  'bufflgj': 24478,
#  'd8qa': 31525,
#  '9r': 14349,
#  'euq29sj': 38081,
#  'p0b': 69110,
#  'c5lefr4': 25108,
#  '9kpdgj1': 14235,
#  'bijhnadh': 22726,
#  '6mrm': 10791,
#  '3qpjiteram0': 7291,
#  '0rhj': 1244,
#  'aj': 17609,
#  'hj': 46724,
#  'r4jjxdk22e': 75424,
#  'cab5dk': 25279,
#  'jkrq0r': 52265,
#  'icrc': 48455,
#  'krd': 54762,
#  'm1vrbjcx': 58061,
#  'nr': 66493,
#  '3frchypk': 6978,
#  'r1chjjij': 75358,
#  'hk': 46739,
#  'j84pq': 51605,
#  'a2': 15814,
#  'bz': 24941,
#  'ff1v': 39999,
#  'kg6qg9': 53901,
#  'mbmupg9xkuex': 60022,
#  '2gl': 5512,
#  'gl': 43462,
#  'ge': 42814,
#  'k5hrx': 53161,
#  'f4ix4irnykb': 39030,
#  'rsbn4': 79205,
#  '8m8qpq2rad': 13108,
#  'fhrc': 40077,
#  'pei2rfhy0': 70319,
#  'gh': 43213,
#  'hn': 46845,
#  'r6jjxb5f': 75470,
#  'cljkfb121qgm2mclee': 27880,
#  'mhpf12b4arq': 61310,
#  'plk': 71695,
#  'i8': 48211,
#  'qrmms5': 74810,
#  '2fp': 5495,
#  '4cpjy0': 8113,
#  'ddap2ale': 32040,
#  'eipbd0c': 36487,
#  'rl1': 78427,
#  'pexj39': 70781,
#  'hf4z': 46370,
#  'zkgn4h9a': 100789,
#  't23l': 86971,
#  'rdf': 76157,
#  'a13x': 15795,
#  'vbkj': 93513,
#  '9me': 14273,
#  'tlp2': 89025,
#  'qckrpm': 74489,
#  'j2e5bn': 51474,
#  'jhn': 52102,
#  'vp': 94603,
#  'pqxjnlyrlpq3c': 72499,
#  'cm0l3e': 27988,
#  'mp': 63222,
#  'cxz6': 31212,
#  'mpvs0': 63298,
#  'p3y': 69197,
#  'xtb5f5qasr': 98731,
#  'xrmrzf1ilxsv': 98596,
#  'ppvjicfmrrekxddi': 72484,
#  '0fhmt': 981,
#  '4vl': 8501,
#  'aalm336chgur': 16084,
#  'me6yaridi': 60429,
#  'y2lpe9hpai': 99273,
#  'fhnfmq': 40075,
#  'qlchvc': 74673,
#  'duajj': 35258,
#  'eb': 35977,
#  '6ndih': 10804,
#  'jqed': 52605,
#  'x1cgdtvmdy965': 97495,
#  'pi': 71106,
#  'mr1jer': 63401,
#  'pq': 72486,
#  'aacvkc': 16078,
#  '0lzi3': 1104,
#  '5pzk8': 9551,
#  'vrd': 94666,
#  'hfr': 46407,
#  '1mci': 3911,
#  'nqh9r': 66481,
#  'j5ve': 51543,
#  '0rn': 1246,
#  'abfb': 16187,
#  'qqlk': 74786,
#  'lkqrh0': 56986,
#  'mkhnya': 62203,
#  'uc': 90938,
#  'qhq': 74592,
#  '5kajhr1efqr': 9422,
#  '2h5b8z': 5522,
#  'slfg3': 83048,
#  '2tpmif': 5914,
#  '58pcd5emb': 9110,
#  '0sc3': 1259,
#  '0s9': 1257,
#  '3c': 6867,
#  '1r': 4046,
#  'jjt': 52246,
#  '33': 6305,
#  'admicj': 16892,
#  '4a3': 8053,
#  'ap': 18931,
#  'sounds': 83795,
#  'wishful': 96603,
#  'guessing': 44643,
#  'mean': 60452,
#  'peace': 70227,
#  'process': 73131,
#  'say': 80430,
#  'palestineans': 69499,
#  'negociate': 65208,
#  'founded': 41258,
#  'predictions': 72665,
#  'test': 88123,
#  'table': 87276,
#  '18': 3247,
#  'months': 62892,
#  'prove': 73551,
#  'fault': 39560,
#  'known': 54509,
#  'accepted': 16409,
#  'terms': 88061,
#  'israelis': 51129,
#  'palestinenans': 69500,
#  'ready': 76229,
#  'statehood': 84945,
#  'politics': 72031,
#  'palestinean': 69498,
#  'leadership': 55854,
#  'fractions': 41360,
#  'aso': 19846,
#  'saying': 80434,
#  'reasons': 76317,
#  'make': 59153,
#  'arabs': 19316,
#  'stall': 84816,
#  'negotiations': 65218,
#  'california': 25421,
#  'oranges': 68236,
#  'sharper': 81866,
#  'regards': 76808,
#  'shouldn': 82184,
#  'allowed': 18006,
#  'msg': 63575,
#  'force': 41042,
#  'food': 40988,
#  'enhance': 37225,
#  'salt': 80134,
#  'option': 68165,
#  'eater': 35963,
#  'commerical': 28530,
#  'leave': 55912,
#  'include': 49409,
#  'packet': 69382,
#  'packets': 69383,
#  'desire': 33034,
#  'pepper': 70442,
#  'mustard': 64024,
#  'ketchup': 53784,
#  'pickles': 71140,
#  'options': 68169,
#  'treat': 89860,
#  'way': 95674,
#  'wouldn': 97032,
#  'shove': 82192,
#  'condiments': 29025,
#  'throat': 88615,
#  'wfl': 96054,
#  'wondering': 96879,
#  'shed': 81919,
#  'light': 56556,
#  'electronic': 36635,
#  'odometers': 67464,
#  'remember': 77149,
#  'total': 89373,
#  'elapsed': 36574,
#  'mileage': 61598,
#  'kind': 54125,
#  'memory': 60760,
#  'stable': 84757,
#  'reliable': 77047,
#  'non': 66154,
#  'volatile': 94485,
#  'independent': 49537,
#  'outside': 68760,
#  'battery': 21794,
#  '10': 1469,
#  'years': 99608,
#  'life': 56530,
#  'vehicle': 93654,
#  'amazed': 18178,
#  'expected': 38604,
#  'length': 56099,
#  'gizmos': 43419,
#  'doing': 34642,
#  'breaking': 24008,
#  'legal': 55989,
#  'ramifications': 75779,
#  'selling': 81319,
#  'used': 92603,
#  'car': 25717,
#  'replaced': 77333,
#  'odometer': 67463,
#  'starts': 84925,
#  'miles': 61599,
#  '100': 1470,
#  '200': 4307,
#  '300k': 6063,
#  'actual': 16709,
#  'looks': 57254,
#  'fraud': 41445,
#  'fairly': 39309,
#  'easy': 35955,
#  'price': 72952,
#  'tell': 87908,
#  'buyer': 24799,
#  'thanks': 88277,
#  'insight': 50119,
#  'archive': 19390,
#  'graphics': 44152,
#  'resources': 77627,
#  'list': 56790,
#  'part1': 69809,
#  'modified': 62646,
#  '1993': 3497,
#  '04': 568,
#  '17': 3131,
#  'computer': 28881,
#  'resource': 77624,
#  'listing': 56800,
#  'weekly': 95869,
#  'posting': 72314,
#  'april': 19224,
#  'faqs': 39435,
#  'including': 49414,
#  'available': 20583,
#  'site': 82719,
#  'pit': 71358,
#  'manager': 59275,
#  'mit': 61999,
#  'alias': 17890,
#  'rtfm': 79248,
#  '172': 3150,
#  '27': 5071,
#  'directory': 33751,
#  'pub': 73796,
#  'usenet': 92613,
#  'news': 65517,
#  'answers': 18759,
#  'archived': 19391,
#  'article': 19689,
#  'server': 81560,
#  'machine': 58818,
#  'send': 81378,
#  'message': 60923,
#  'containing': 29452,
#  'keyword': 53864,
#  'help': 46158,
#  'quotes': 75179,
#  'body': 23430,
#  'places': 71520,
#  'item': 51219,
#  'information': 49822,
#  'items': 51220,
#  'changed': 26653,
#  'arranged': 19614,
#  'subjects': 85746,
#  'order': 68285,
#  'fir': 40353,
#  '63k': 10009,
#  'limit': 56629,
#  'plan': 71540,
#  'changing': 26660,
#  'headers': 45929,
#  'soon': 83712,
#  'careful': 25778,
#  'keys': 53849,
#  'remain': 77117,
#  'subject': 85737,
#  '3d': 6880,
#  'editors': 36206,
#  'public': 73802,
#  'domain': 34668,
#  'free': 41468,
#  'shareware': 81852,
#  'systems': 86883,
#  'plotting': 71719,
#  'packages': 69376,
#  'molecular': 62728,
#  'visualization': 94246,
#  'stuff': 85631,
#  'thinking': 88493,
#  'making': 59171,
#  'bi': 22628,
#  'lines': 56698,
#  'character': 26694,
#  'added': 16795,
#  'prepended': 72778,
#  'removed': 77197,
#  'diff': 33534,
#  'locate': 57122,
#  'changes': 26659,
#  'text': 88191,
#  'copyright': 29789,
#  '1992': 3495,
#  'nikolaos': 65819,
#  'fotis': 41246,
#  'copy': 29778,
#  'freely': 41480,
#  'provided': 73564,
#  'notice': 66363,
#  'intact': 50265,
#  'compiled': 28732,
#  'nick': 65729,
#  'nfotis': 65602,
#  'theseas': 88435,
#  'ntua': 66634,
#  'gr': 44024,
#  'contact': 29439,
#  'updates': 92380,
#  'corrections': 29890,
#  'disclaimer': 33867,
#  'guarantee': 44599,
#  'accuracy': 16523,
#  'document': 34584,
#  'risk': 78304,
#  'mainly': 59107,
#  'guide': 44658,
#  'software': 83557,
#  'suggest': 85996,
#  'reading': 76218,
#  'comp': 28621,
#  'image': 48959,
#  'analysis': 18442,
#  'entitled': 37358,
#  'date': 31851,
#  'frequently': 41526,
#  'asked': 19826,
#  'john': 52392,
#  'grieggs': 44337,
#  'jpl': 52570,
#  'devvax': 33286,
#  'nasa': 64845,
#  'poster': 72305,
#  'official': 67538,
#  'included': 49410,
#  'comments': 28523,
#  'braces': 23891,
#  'contents': 29487,
#  'archie': 19376,
#  'notes': 66354,
#  'ftp': 41728,
#  'eric': 37675,
#  'haines': 45267,
#  'servers': 81563,
#  'oriented': 68372,
#  'bbses': 21875,
#  'ray': 75973,
#  'tracing': 89540,
#  'related': 76993,
#  'mailing': 59081,
#  'lists': 56806,
#  'commercial': 28525,
#  'scene': 80585,
#  'description': 32989,
#  'languages': 55483,
#  'solids': 83625,
#  'formats': 41160,
#  'part2': 69811,
#  'processing': 73134,
#  'display': 34113,
#  'part3': 69812,
#  '11': 1912,
#  'generators': 42934,
#  'geographical': 43024,
#  'data': 31820,
#  'maps': 59445,
#  'files': 40237,
#  '12': 2222,
#  'scanners': 80537,
#  'digitized': 33597,
#  '13': 2425,
#  'background': 21266,
#  'imagery': 48971,
#  'textures': 88207,
#  'datafiles': 31834,
#  '14': 2593,
#  'introduction': 50596,
#  'rendering': 77220,
#  'algorithms': 17878,
#  'buffer': 24470,
#  'depth': 32907,
#  '15': 2777,
#  'geometric': 43036,
#  'teapot': 87746,
#  'space': 83871,
#  'shuttle': 82292,
#  '16': 2939,
#  'annotation': 18675,
#  'scientific': 80737,
#  '19': 3353,
#  'gis': 43372,
#  'future': 41947,
#  'additions': 16809,
#  'info': 49800,
#  'crossposted': 30553,
#  'advised': 17048,
#  'search': 81086,
#  'groups': 44446,
#  'usually': 92683,
#  'sysadmin': 86860,
#  'articles': 19690,
#  'posted': 72303,
#  'times': 88854,
#  'month': 62888,
#  'kept': 53754,
#  'field': 40135,
#  'inria': 50081,
#  'graphlib': 44163,
#  'mirrors': 61823,
#  'accesible': 16414,
#  'wais': 95384,
#  'enuxva': 37403,
#  'eas': 35927,
#  'asu': 20065,
#  'port': 72205,
#  '8000': 12267,
#  'digest': 33573,
#  'type': 90580,
#  'numbered': 66683,
#  'purposes': 74007,
#  'indexing': 49555,
#  'place': 71514,
#  'monitors': 62816,
#  'maasinfo': 58771,
#  'robert': 78728,
#  'maas': 58770,
#  'rem': 77112,
#  'btr': 24387,
#  'com': 28405,
#  'general': 42913,
#  'switch': 86657,
#  'swiss': 86655,
#  'academic': 16371,
#  'network': 65377,
#  'switzerland': 86672,
#  'interactive': 50328,
#  'telnet': 87917,
#  'nic': 65707,
#  'ch': 26559,
#  '130': 2426,
#  '59': 9117,
#  'login': 57186,
#  'info_service': 49801,
#  'periodic': 70527,
#  'postings': 72316,
#  '00index': 235,
#  'typing': 90604,
#  'word': 96926,
#  'decide': 32200,
#  'fetch': 39948,
#  'following': 40961,
#  'methods': 61021,
#  'user': 92618,
#  'anonymous': 18730,
#  'internet': 50444,
#  'style': 85671,
#  'address': 16818,
#  'prompted': 73331,
#  'password': 69924,
#  'cd': 26213,
#  'rfc': 77987,
#  '822': 12442,
#  '400': 7455,
#  'ou': 68632,
#  'prmd': 73077,
#  'admd': 16890,
#  'arcom': 19403,
#  'bodypart': 23433,
#  'receive': 76388,
#  'instructions': 50219,
#  'required': 77469,
#  'header': 45927,
#  'service': 81565,
#  'requested': 77460,
#  'appreciated': 19162,
#  'newsgroups': 65531,
#  'au': 20315,
#  '139': 2527,
#  'aussie': 20432,
#  'nz': 66876,
#  'funet': 41866,
#  'fi': 40082,
#  '128': 2359,
#  '214': 4526,
#  'finland': 40332,
#  'eur': 38082,
#  'th': 88256,
#  ...}

# %%
# Querying a document related to one of the document in test data
query = preprocessing_model.transform(X_test.iloc[2])

# %%
X_test[0][2]
# Out:
# "Devorski unfortunately helped to taint an otherwise brilliant display\nby MacLean.  The Canucks tied up the Jets so tightly that I thought that\nthey were mailing them.\n\nBTW, Greg...next time, don't fall asleep in geography class, it's pretty\nsad when a fellow in Norway can spell Winnipeg properly and a guy in\nNorth America can't.\n\nOne more thing...how LONG has Vancouver been in the NHL?  How many\nchampionships do they have?  \n\nOh yeah...and I CAN go to the Arena and see not one, not two, but\n*six* championship banners hanging from the rafters.  3 Stanley Cup\nbanners, and 3 Avco Cup banners.  My NHL guide says that Vancouver has\nwon the Cup once (as many times as the rockin' town of Kenora has won it!)"

# %%
query.shape
# Out:
# (1, 500)

# %%
query
# Out:
# array([[ 6.70776812e-02, -2.13308001e-02, -3.66787818e-02,
#          1.35004159e-03, -5.39209418e-02, -2.84242175e-02,
#          2.27992511e-02, -1.87605971e-02, -2.86120636e-02,
#         -1.86597133e-02,  1.08582297e-02,  7.24349705e-03,
#          1.22538605e-03,  1.19576105e-03, -9.95182588e-03,
#         -5.81118918e-03, -2.10846215e-03,  5.32914320e-03,
#          7.36690105e-03,  1.39568937e-02,  4.01187776e-04,
#         -7.05393467e-03, -2.46277700e-03, -1.59074203e-02,
#         -5.73822567e-05,  8.97679018e-03, -4.73598948e-03,
#         -7.10031581e-03, -1.91122757e-02, -1.18174578e-03,
#         -1.86358294e-02, -7.00502265e-03, -1.41995253e-02,
#         -4.69208871e-03,  6.84998824e-03,  1.44047380e-02,
#          1.63741131e-02, -9.60423187e-03, -1.94316445e-03,
#          1.46567761e-02, -7.12920614e-03, -4.39824897e-03,
#         -6.95460889e-03, -1.40301592e-02, -8.84213884e-03,
#         -2.48615507e-02,  1.25617655e-02,  6.46663767e-03,
#         -5.49384981e-03,  1.83170149e-02, -2.68150679e-02,
#         -2.73829436e-02,  1.82891290e-02, -1.20628844e-03,
#          5.57639169e-02,  2.76473239e-02,  7.43667076e-03,
#         -6.91798782e-04,  4.90542713e-03,  9.41628770e-03,
#         -1.80973289e-02,  3.91985030e-02, -9.35847094e-03,
#          8.34313757e-03,  2.48370748e-02, -2.10721554e-02,
#          2.33022684e-03, -8.98570977e-03, -1.23443070e-02,
#          1.56736583e-02, -7.10874494e-03, -1.33166060e-03,
#          1.48699512e-02,  2.58559513e-03,  5.85957218e-04,
#         -2.20859785e-02,  1.47913581e-02,  6.60810268e-03,
osine similarity
from sklearn.metrics.pairwise import cosine_similarity
distance_matrix = cosine_similarity(svd_matrix_train,query)

# %%
print(distance_matrix)
# Out:
# [[0.01704803]
#  [0.14591162]
#  [0.01539193]
#  ...
#  [0.03049251]
#  [0.01768989]
#  [0.08865318]]

# %%
flat = distance_matrix.flatten()

# %%
flat
# Out:
# array([0.01704803, 0.14591162, 0.01539193, ..., 0.03049251, 0.01768989,
#        0.08865318])

# %%
sort_indices = np.argsort(flat)

# %%
sort_indices
# Out:
# array([11041,  5527,   883, ...,  4275,  7731,  4931])

# %%
sort_indices[-5:]
# Out:
# array([1597, 1684, 4275, 7731, 4931])

# %%
# Write a  Function to return indices of top n elemets

# %%
distance_matrix[4931]
# Out:
# array([0.41983427])

# %%
distance_matrix[7731]
# Out:
# array([0.41738627])

# %%
X_test[0][2]
# Out:
# "Devorski unfortunately helped to taint an otherwise brilliant display\nby MacLean.  The Canucks tied up the Jets so tightly that I thought that\nthey were mailing them.\n\nBTW, Greg...next time, don't fall asleep in geography class, it's pretty\nsad when a fellow in Norway can spell Winnipeg properly and a guy in\nNorth America can't.\n\nOne more thing...how LONG has Vancouver been in the NHL?  How many\nchampionships do they have?  \n\nOh yeah...and I CAN go to the Arena and see not one, not two, but\n*six* championship banners hanging from the rafters.  3 Stanley Cup\nbanners, and 3 Avco Cup banners.  My NHL guide says that Vancouver has\nwon the Cup once (as many times as the rockin' town of Kenora has won it!)"

# %%
X_train[0][4931]
# Out:
# 'Ten years ago, the number of Europeans in the NHL was roughly a quarter\nof what it is now. Going into the 1992/93 season, the numbers of Euros on\nNHL teams have escalated to the following stats:\n\nCanadians: 400\nAmericans: 100\nEuropeans: 100\n\n   Please note that these numbers are rounded off, and taken from the top\n25 players on each of the 24 teams. My source is the Vancouver Sun.\n\n   Here\'s the point: there are far too many Europeans in the NHL. I am sick\nof watching a game between an American and a Canadian team (let\'s say, the\nRed Wings and the Canucks) and seeing names like "Bure" "Konstantinov" and\n"Borshevshky". Is this North America or isn\'t it? Toronto, Detriot, Quebec,\nand Edmonton are particularly annoying, but the numbers of Euros on other\nteams is getting worse as well. \n\n    I live in Vancouver and if I hear one more word about "Pavel Bure, the\nRussian Rocket" I will completely throw up. As it is now, every time I see\nthe Canucks play I keep hoping someone will cross-check Bure into the plexiglassso hard they have to carry him out on a stretcher. (By the way, I\'m not a\nCanucks fan to begin with ;-). \n\n    Okay, the stretcher remark was a little carried away. But the point is that\nI resent NHL owners drafting all these Europeans INSTEAD of Canadians (and\nsome Americans). It denies young Canadians the opportunity to play in THEIR\nNORTH AMERICAN LEAGUE and instead gives it to Europeans, who aren\'t even\nbetter hockey players. It\'s all hype. This "European mystique" is sickening,\nbut until NHL owners get over it, Canadian and American players will continue\nto have to fight harder to get drafted into their own league.\n\n    With the numbers of Euros in the NHL escalating, the problem is clearly\nonly getting worse.\n\n    I\'m all for the creation of a European Hockey League, and let the Bures\nand Selannes of the world play on their own continent.\n\n    I just don\'t want them on mine.\n\n\n \n \n-- \nRichard J. Rauser        "You have no idea what you\'re doing."\nrauser@sfu.ca            "Oh, don\'t worry about that. We\'re professional\nWNI                          outlaws - we do this for a living."'
